# %%
# Import packages
import csv
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import nltk

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Fan Kai
# [nltk_data]     Jie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Fan Kai
# [nltk_data]     Jie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load tweets data
data = []
with open('tweets_DM.json', 'r') as f:
    for i in f:
        data.append(json.loads(i))

# Flatten json into dataframe
df = pd.json_normalize(data)

# %%
# Rename _source.tweet.tweet_id to tweet_id for merging with emotion and identification data later
df.rename(columns={'_source.tweet.tweet_id' : 'tweet_id'}, inplace=True)

# %%
# Load emotion and identification data
emotion = pd.read_csv('emotion.csv')
identification = pd.read_csv('data_identification.csv')

# %%
# Visualise emotion data
emotion
# Out:
#          tweet_id       emotion
# 0        0x3140b1       sadness
# 1        0x368b73       disgust
# 2        0x296183  anticipation
# 3        0x2bd6e1           joy
# 4        0x2ee1dd  anticipation
# ...           ...           ...
# 1455558  0x38dba0           joy
# 1455559  0x300ea2           joy
# 1455560  0x360b99          fear
# 1455561  0x22eecf           joy
# 1455562  0x2fb282  anticipation
#
# [1455563 rows x 2 columns]

# %%
# Visualise identification data
identification
# Out:
#          tweet_id identification
# 0        0x28cc61           test
# 1        0x29e452          train
# 2        0x2b3819          train
# 3        0x2db41f           test
# 4        0x2a2acc          train
# ...           ...            ...
# 1867530  0x227e25          train
# 1867531  0x293813          train
# 1867532  0x1e1a7e          train
# 1867533  0x2156a5          train
# 1867534  0x2bb9d2          train
#
# [1867535 rows x 2 columns]

# %%
# Visualise dataframe
df
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 2           232  hashtag_tweets  2017-12-25 04:39:20  tweets
# 3           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 4           989  hashtag_tweets  2016-01-08 17:18:59  tweets
# ...         ...             ...                  ...     ...
# 1867530     827  hashtag_tweets  2015-05-12 12:51:52  tweets
# 1867531     368  hashtag_tweets  2017-10-02 17:54:04  tweets
# 1867532     498  hashtag_tweets  2016-10-10 11:04:32  tweets
# 1867533     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1867534     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                   _source.tweet.hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# 3                                     []  0x1cd5b0
# 4                                     []  0x2de201
# ...                                  ...       ...
# 1867530  [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                               []  0x29d0cb
# 1867532                               []  0x2a6a4f
# 1867533                               []  0x24faed
# 1867534                    [Sundayvibes]  0x34be8c
#
#                                         _source.tweet.text
# 0        People who post "add me on #Snapchat" must be ...
# 1        @brianklaas As we see, Trump is dangerous to #...
# 2        Confident of your obedience, I write to you, k...
# 3                      Now ISSA is stalking Tasha 😂😂😂 <LH>
# 4        "Trust is not the same as faith. A friend is s...
# ...                                                    ...
# 1867530  When you buy the last 2 tickets remaining for ...
# 1867531  I swear all this hard work gone pay off one da...
# 1867532  @Parcel2Go no card left when I wasn't in so I ...
# 1867533  Ah, corporate life, where you can date <LH> us...
# 1867534             Blessed to be living #Sundayvibes <LH>
#
# [1867535 rows x 7 columns]

# %%
# Merge df and identification data first as they have the same number of rows
overall = pd.merge(df, identification, on='tweet_id')

# %%
# Visualise dataframe after 1st merging
overall
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 2           232  hashtag_tweets  2017-12-25 04:39:20  tweets
# 3           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 4           989  hashtag_tweets  2016-01-08 17:18:59  tweets
# ...         ...             ...                  ...     ...
# 1867530     827  hashtag_tweets  2015-05-12 12:51:52  tweets
# 1867531     368  hashtag_tweets  2017-10-02 17:54:04  tweets
# 1867532     498  hashtag_tweets  2016-10-10 11:04:32  tweets
# 1867533     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1867534     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                   _source.tweet.hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# 3                                     []  0x1cd5b0
# 4                                     []  0x2de201
# ...                                  ...       ...
# 1867530  [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                               []  0x29d0cb
# 1867532                               []  0x2a6a4f
# 1867533                               []  0x24faed
# 1867534                    [Sundayvibes]  0x34be8c
#
#                                         _source.tweet.text identification
# 0        People who post "add me on #Snapchat" must be ...          train
# 1        @brianklaas As we see, Trump is dangerous to #...          train
# 2        Confident of your obedience, I write to you, k...           test
# 3                      Now ISSA is stalking Tasha 😂😂😂 <LH>          train
# 4        "Trust is not the same as faith. A friend is s...           test
# ...                                                    ...            ...
# 1867530  When you buy the last 2 tickets remaining for ...           test
# 1867531  I swear all this hard work gone pay off one da...           test
# 1867532  @Parcel2Go no card left when I wasn't in so I ...           test
# 1867533  Ah, corporate life, where you can date <LH> us...          train
# 1867534             Blessed to be living #Sundayvibes <LH>          train
#
# [1867535 rows x 8 columns]

# %%
# Split overall dataframe into train and test dataframes
train = overall[overall['identification'] == 'train']
test = overall[overall['identification'] == 'test']

# %%
# Visualise train dataframe
train
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 3           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 5           120  hashtag_tweets  2015-06-11 04:44:05  tweets
# 6          1021  hashtag_tweets  2015-08-18 02:30:07  tweets
# ...         ...             ...                  ...     ...
# 1867526      94  hashtag_tweets  2016-12-26 02:44:07  tweets
# 1867527     627  hashtag_tweets  2015-04-01 08:14:56  tweets
# 1867528     274  hashtag_tweets  2016-11-17 23:46:22  tweets
# 1867533     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1867534     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                 _source.tweet.hashtags  tweet_id  \
# 0                           [Snapchat]  0x376b20
# 1        [freepress, TrumpLegacy, CNN]  0x2d5350
# 3                                   []  0x1cd5b0
# 5            [authentic, LaughOutLoud]  0x1d755c
# 6                                   []  0x2c91a8
# ...                                ...       ...
# 1867526              [NoWonder, Happy]  0x321566
# 1867527                             []  0x38959e
# 1867528                     [blessyou]  0x2cbca6
# 1867533                             []  0x24faed
# 1867534                  [Sundayvibes]  0x34be8c
#
#                                         _source.tweet.text identification
# 0        People who post "add me on #Snapchat" must be ...          train
# 1        @brianklaas As we see, Trump is dangerous to #...          train
# 3                      Now ISSA is stalking Tasha 😂😂😂 <LH>          train
# 5        @RISKshow @TheKevinAllison Thx for the BEST TI...          train
# 6             Still waiting on those supplies Liscus. <LH>          train
# ...                                                    ...            ...
# 1867526  I'm SO HAPPY!!! #NoWonder the name of this sho...          train
# 1867527  In every circumtance I'd like to be thankful t...          train
# 1867528  there's currently two girls walking around the...          train
# 1867533  Ah, corporate life, where you can date <LH> us...          train
# 1867534             Blessed to be living #Sundayvibes <LH>          train
#
# [1455563 rows x 8 columns]

# %%
# Merge train dataframe with emotion dataframe only as emotion dataframe only consists of training labels
train = pd.merge(train, emotion, on='tweet_id')

# %%
# Split the labels column out after merging, so that the index is aligned with the train dataframe
y_train = train.pop('emotion').to_frame()

# %%
# Visualise y_train dataframe
y_train
# Out:
#               emotion
# 0        anticipation
# 1             sadness
# 2                fear
# 3                 joy
# 4        anticipation
# ...               ...
# 1455558           joy
# 1455559           joy
# 1455560           joy
# 1455561           joy
# 1455562           joy
#
# [1455563 rows x 1 columns]

# %%
# Visualise train dataframe to confirm that it is only left with the features
train
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 2           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 3           120  hashtag_tweets  2015-06-11 04:44:05  tweets
# 4          1021  hashtag_tweets  2015-08-18 02:30:07  tweets
# ...         ...             ...                  ...     ...
# 1455558      94  hashtag_tweets  2016-12-26 02:44:07  tweets
# 1455559     627  hashtag_tweets  2015-04-01 08:14:56  tweets
# 1455560     274  hashtag_tweets  2016-11-17 23:46:22  tweets
# 1455561     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1455562     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                 _source.tweet.hashtags  tweet_id  \
# 0                           [Snapchat]  0x376b20
# 1        [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                                   []  0x1cd5b0
# 3            [authentic, LaughOutLoud]  0x1d755c
# 4                                   []  0x2c91a8
# ...                                ...       ...
# 1455558              [NoWonder, Happy]  0x321566
# 1455559                             []  0x38959e
# 1455560                     [blessyou]  0x2cbca6
# 1455561                             []  0x24faed
# 1455562                  [Sundayvibes]  0x34be8c
#
#                                         _source.tweet.text identification
# 0        People who post "add me on #Snapchat" must be ...          train
# 1        @brianklaas As we see, Trump is dangerous to #...          train
# 2                      Now ISSA is stalking Tasha 😂😂😂 <LH>          train
# 3        @RISKshow @TheKevinAllison Thx for the BEST TI...          train
# 4             Still waiting on those supplies Liscus. <LH>          train
# ...                                                    ...            ...
# 1455558  I'm SO HAPPY!!! #NoWonder the name of this sho...          train
# 1455559  In every circumtance I'd like to be thankful t...          train
# 1455560  there's currently two girls walking around the...          train
# 1455561  Ah, corporate life, where you can date <LH> us...          train
# 1455562             Blessed to be living #Sundayvibes <LH>          train
#
# [1455563 rows x 8 columns]

# %%
# Visualise test dataframe after merging
test
# Out:
#          _score          _index           _crawldate   _type  \
# 2           232  hashtag_tweets  2017-12-25 04:39:20  tweets
# 4           989  hashtag_tweets  2016-01-08 17:18:59  tweets
# 9            66  hashtag_tweets  2015-09-09 09:22:55  tweets
# 30          104  hashtag_tweets  2015-10-10 14:33:26  tweets
# 33          310  hashtag_tweets  2016-10-23 08:49:50  tweets
# ...         ...             ...                  ...     ...
# 1867525     602  hashtag_tweets  2016-12-10 18:01:00  tweets
# 1867529     598  hashtag_tweets  2015-01-04 14:40:55  tweets
# 1867530     827  hashtag_tweets  2015-05-12 12:51:52  tweets
# 1867531     368  hashtag_tweets  2017-10-02 17:54:04  tweets
# 1867532     498  hashtag_tweets  2016-10-10 11:04:32  tweets
#
#                     _source.tweet.hashtags  tweet_id  \
# 2                             [bibleverse]  0x28b412
# 4                                       []  0x2de201
# 9        [materialism, money, possessions]  0x218443
# 30                    [GodsPlan, GodsWork]  0x2939d5
# 33                                      []  0x26289a
# ...                                    ...       ...
# 1867525                                 []  0x2913b4
# 1867529                                 []  0x2a980e
# 1867530    [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                                 []  0x29d0cb
# 1867532                                 []  0x2a6a4f
#
#                                         _source.tweet.text identification
# 2        Confident of your obedience, I write to you, k...           test
# 4        "Trust is not the same as faith. A friend is s...           test
# 9        When do you have enough ? When are you satisfi...           test
# 30       God woke you up, now chase the day #GodsPlan #...           test
# 33       In these tough times, who do YOU turn to as yo...           test
# ...                                                    ...            ...
# 1867525  "For this is the message that ye heard from th...           test
# 1867529  "There is a lad here, which hath five barley l...           test
# 1867530  When you buy the last 2 tickets remaining for ...           test
# 1867531  I swear all this hard work gone pay off one da...           test
# 1867532  @Parcel2Go no card left when I wasn't in so I ...           test
#
# [411972 rows x 8 columns]

# %%
# Check if there are any missing values in train dataframe
train.isna().sum()

# Conclusion: There are no missing values in train dataframe
# Out:
# _score                    0
# _index                    0
# _crawldate                0
# _type                     0
# _source.tweet.hashtags    0
# tweet_id                  0
# _source.tweet.text        0
# identification            0
# dtype: int64

# %%
# Check if there are any missing values in test dataframe
test.isna().sum()

# Conclusion: There are no missing values in test dataframe
# Out:
# _score                    0
# _index                    0
# _crawldate                0
# _type                     0
# _source.tweet.hashtags    0
# tweet_id                  0
# _source.tweet.text        0
# identification            0
# dtype: int64

# %%
# To pre-process tweets by removing irrelavant characters and standardise all to lowercase
def preprocess_tweet(tweet):
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE) # To remove URLs
    tweet = re.sub(r'\@w+', '', tweet) # To remove mentions
    tweet = re.sub(r'#', '', tweet) # To remove hashtags
    tweet = re.sub(r'\d+', '', tweet) # To remove numbers
    tweet = tweet.lower() # Convert to lowercase
    tweet = re.sub(r'\s+', ' ', tweet).strip() # To remove extra whitespace
    return tweet

# %%
# Pre-process tweets in train dataframe
train_processed = [preprocess_tweet(r['_source.tweet.text']) for i, r in train.iterrows()]

# %%
# Visualise train_processed dataframe
train_processed
# Out:
# ['people who post "add me on snapchat" must be dehydrated. cuz man.... that\'s <lh>',
#  '@brianklaas as we see, trump is dangerous to freepress around the world. what a <lh> <lh> trumplegacy. cnn',
#  'now issa is stalking tasha 😂😂😂 <lh>',
#  '@riskshow @thekevinallison thx for the best time tonight. what stories! heartbreakingly <lh> authentic laughoutloud good!!',
#  'still waiting on those supplies liscus. <lh>',
#  'love knows no gender. 😢😭 <lh>',
#  '@dstvngcare @dstvng more highlights are being shown than actual sports! who watches triathlon highlights anyway? <lh> leaguecup',
#  'the ssm debate; <lh> (a manufactured fantasy used to distract the ignorant masses from their mundane lives) v gender diversity (a m......',
#  "i love suffering 🙃🙃 i love when valium does nothing to help 🙃🙃 i love when my doctors say that they've done all they can 🙃🙃 <lh>",
#  'can someone tell my why my feeds scroll back to the same tweets that i saw min ago? pissed!',
#  'you know you research butterflies when predictive text autocorrects "but" to "butterfly" justgradstudentthings ecology <lh>',
#  "my brother didn't tell me he was going to horror nights tomorrow so now i'm not going <lh>",
#  'on a scale of kylie jenner-heidi klum, i consider myself the heidi klum of halloween. <lh>',
#  'progress at house meyer, pre galv sub frame going in. maintenancefreesubframe evatech <lh> bendingcomposite inovarsandtoncrew',
#  'vomi post birthday celebrations! late_post <lh> <lh>',
#  'one of my dreams come true a couple of days ago! <lh> tig',
#  'thankful for another day of life 🙏🏾. blessed✨',
#  'giving thanks to my lord and savior for allowing me to wake up and see another wonderful day in jesus name i pray amen. thankulord <lh>',
#  '@grayconnolly fmd...you idiots keep spending our $$ just to keep lightweight crabb in a job ...shame <lh> <lh>',
#  "@realdonaldtrump do you even care how much people - a lot of people - dislike you and think you're crazy?",
#  'i’ll never be half the man pat tillman was. <lh>',
#  "when you just want to be with your family but they're on the other side of the country 😭👎🏻homesick militarywifeproblems",
#  "@carolinemutoko @ukenyatta ballot is stronger than the bullet may peace prevail god'swin",
#  'the fire within is all driven by needing to be above average. when your above, their smile will disappear <lh> workhardplayhard deft',
#  'no wait okay so fuck people who think tattoos are bad but for some reason the idea of a tattoo that says “regret” on it just tickles me',
#  'millions of purple cushion-footed balderdash ! <lh>',
#  '@usps @uspshelp ... why is it that all of my packages have been out for "delivery" for hours and still haven\'t shown up? <lh> <lh>',
#  '@secy_state_us @johnpodesta are u drinking russian vodka? you are a disgrace and do not belong in our wh administration. <lh>',
#  '@nufc @skybetchamp @nu_foundation some <lh> <lh> we need to see some more this season nufc',
#  'sundaybreakfast @bbccornwall : @jameslangstaff on <lh> in prisons, @revrichardcoles on strictly (and the rise of the celebrity vicar)/',
#  'follow for <lh> next hours ? iphonex windians <lh> clevelandindians mothermovie detroithomecoming <lh> retweeet bignews',
#  "today's <lh> trigger was seeing a window cleaner at work. i had a moment. i'm ok now. keepfighting roadtorecovery",
#  '@bbuk did shaun actually nominate chad and sarah just because there in a relationship <lh>',
#  'hangry and ready to snap. hangry <lh> needfood 😐',
#  "@lexadubs the gag is you're involved but only through an algorithm so you're <lh> this month",
#  'hey ravens defense thanks for getting my fantasy football day off right....awful👎🏼👎🏼',
#  '@scottwarner red sox/patriots fans. <lh>',
#  'i may have just lost my jaw to the floor upon seeing how <lh> and <lh> you',
#  "booked an amazing project! can't share deets yet, but it's exciting! <lh> @multi_ethnicmgt @ddoartists @irenecabreranyc @ginamanfredi",
#  'started the day with patients ended with <lh> 🤦🏼\u200d♀️',
#  '<lh> is the way, the truth, and the life',
#  '@peplamb there is no <lh> if @realdonaldtrump is president. resign.',
#  '@lirr and now it smells like onions.... <lh> lirr',
#  'enjoyable runout today at st asaph vs caerwys. good match and good reception, i put some miles in today ready for the season 🏃🤙🏻ready',
#  'the moments in your life are only once life <lh> <lh> <lh> <lh> <lh> august , at :pm',
#  '@rubey_lcheek great game tonight swanley boy <lh> :) x',
#  '<lh> for brother & sister in christ that lost thier yearold.pray gods peace, comfort&strength be with them during this time in jesusname',
#  '<lh> that’s how we women are. so we are tweeting <lh> till we are heard hartas estamos las mujeres twiteamos hartas hasta que se oiga',
#  "saw the county's bitch today. pulled up next to him and he froze. couldn't help but look at me when i screamed hi jesse and waved. scared?",
#  "who's ready for thanksgiving!? <lh> <lh> <lh> <lh>",
#  '@sydbell @strutcancer £ donates to macmillan 👍😎👌 <lh> !!',
#  "@aislingdee i hope that's a good thing? <lh>",
#  '@traffitise thanks for following <lh>',
#  '@tyrogoldenstein was this <lh> pavillion the führerbunker for those nazis?😏🤣😂 bostonresist against hatespeechrally',
#  'its gonna be pretty hard to pay these salaries to players when no one shows up or watches on tv. show respect and play ball. nfl nba <lh>',
#  'about to go on break in minutes 😇🙌🏽 hungry😩🙄😂',
#  '@broderick @mckelvie what in the world is this and who overcharged you and told you it was british?! mineeyes <lh> smh',
#  '<lh> <lh> <lh> nimrodel beckons and geranosaurus baffles chaos sings a melancholy strain "mog, where is my fresh string beans?"',
#  'glad to be able to prepare and drop my little girl everyday ! <lh> happyness <lh>',
#  '<lh> keys already and a gift bish molly wtf you doing',
#  'i want that frank ocean phone cover <lh>',
#  '@cbsnews another senator sell out...partyovercountry <lh>',
#  'just found out great news! making a comeback! <lh>',
#  'always remember.. <lh> speaks louder than stardom...',
#  "internet is back to normal almost hours ago, after connection problems last night. i'm feeling <lh> tonight!",
#  'today is a rare day - if you take your birthday and add your age, you will get ! try it for yourself ! <lh> onceinalifetime',
#  'happy thanksgiving <lh> 🦃🦃',
#  '<lh> reading today shows in john , as a disciple of christ, <lh> is glorified by us "bearing much fruit." i want my life to glorify god!',
#  'antifa hooligans are walking to dc from charlottesville today! those <lh> idiots & numbskulls are playing with fire!!!!!!!!!!!',
#  'own in your neighborhood <lh>',
#  'anyone wants to talk about anything, hit me up. <lh> suicide <lh>',
#  'what difference are you going to make tomorrow on intlpeaceday <lh> help <lh> stophate',
#  'hey inga catfishfight thanks for the follow! (un)follow=(un)follow please visit my <lh> handle <lh> for <lh> <lh> qu…',
#  '<lh> and <lh> to @zahranabhwun @quinn_w_two_ns <lh> <lh>',
#  'we should take shooting valley girls for like, saying like all the time really and push it the <lh> hand.',
#  "a best friend is the one who can look at you with the biggest smile on your face and still know something's wrong. <lh> <lh> rel…",
#  'anybody tell me vivegam censor copy is leaked 😢😥😥😥sad',
#  "i want to help but i don't have a boat or know where to go! <lh> hurricaineharvey",
#  '@ironbowl whowins? be <lh> high expectations for both! since @nicksabanuofa not the norm!wareagle',
#  'my hospitality class is now giving away free coffees to the homeless for this years melbourne winter giving <lh> staywarm homeless <lh>',
#  "don't stop the progressive change <lh> is making in you-whilst you're battling with doubt-no ground can be made-settle it-trust jesus!",
#  '@realdonaldtrump look! over there! <lh>',
#  "@jazzystylezatl the dudes at dude.fm say cheers and we're <lh> for the follow!",
#  'happy birthday @keyshiacole oneifthegreats amazing💖',
#  '"and, behold,i come quickly; and my reward is with me, to give every man according as his work shall be." revelation : kjv <lh>',
#  '"create content that teaches. you can’t give up. you need to be consistently awesome." neilpatel <lh> branding startup strategy"l',
#  'the must watch movies list of kannada is increasing year by year!! greatgoing <lh>',
#  'the greatest gift for mankind is love. quotesforlife <lh> <lh> gratitude',
#  "i love it when other drivers let you know there's a cop hiding somewhere by flashing their brights. <lh>",
#  "@bbccasualty but... she's polly, she died already! intentional resemblance casting? <lh>",
#  'few things in the world are more powerful than a positive push. a smile. a world of optimism & <lh> ―richard m. devos givehope givetariro',
#  'and as, i drove off into the abyss, i heard two gun shots and bullets flying past the car <lh>',
#  'penguins mate for life, you can find the man of your life too! women <lh> <lh> ad',
#  'seven in a row! -!!! skol <lh> <lh>',
#  '@imvkohli we are million strong now ♡♡♡ <lh> viratians',
#  '@themondaymommy @fugazilifefb ahead of the curve thankfully. <lh>',
#  '@cbs i may have to do the same to you due to this money grab. <lh> pissedatcbs',
#  'that is a nightmare... homework nightmare <lh> whyyy',
#  'my <lh> niece &lt; seniorhomecoming....soproud',
#  'question: why do you think <lh> puts so much weight on healthy, respectful relationships? wedensdaywisdom',
#  '@sgpt hi suzyq. if you like me; @statustihange and @statusdoel are siblings <lh>',
#  'i never take for granted waking up to see another day blessed😇🙌🏽💕',
#  'maybe someday ill get this whole weight room thing...sigh. <lh>',
#  'honestly i feel for justiceforjazzy i swear she handled this like an angel. <lh> is so proud of you sis this is why i don’t do roomates😡',
#  'we’re really getting new charli, brockhampton, and eminem on the same day <lh>',
#  'god\x92s love is amazing!',
#  'capricorn ♑ <lh> dream',
#  'my car aux works again <lh>',
#  '@someaningless i am <lh> what are you doing this friday?',
#  'don’t wait for everything to be perfect before you decide to enjoy your life. <lh> <lh>',
#  "to be <lh> it's all we want, right?",
#  '@facebook you need to bring back the <lh> reaction for veteransday',
#  'thank youu @missouri river tribes for the guns, powder and native corn ❤️ <lh> <lh> european items',
#  '<lh> <lh> <lh> nori beckons and tanius baffles demeter sings a melancholy strain "students circle network, where is my pie a la mode?"',
#  'closed buy . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  'i woke uo to so much joon content i am truly <lh> 😌🙏',
#  '<lh> that i dont have a curly pube beard or neckbeard hailsatan',
#  'dear love, doors of my toilet will always open for you ❤ <lh> by toiletekpremkatha',
#  'when the conservatives went past at the pride parade and no one cheered <lh>',
#  'subject to whomever it concerns thanks to each and everyone whoever wished me <lh> choose_love ninga_illama_naillaye 😉',
#  'here at fdg <lh>',
#  'so from the hr grind to the hr trap <lh> with the strength to hold my own!!!',
#  '@abpcrickethindi @abpnewstv bleed blue <lh> it',
#  'some people take shit way too seriously!!! <lh> <lh> dramaalert',
#  '✔islam in harmony,reflects truths&no placelies&hypocrisy in it.religion of justice&mercy from great <lh> has the power over all.quranist',
#  'why are the countries that <lh> in humanrights not addressing the issues happening in burma?',
#  'push the <lh> everyday. be some special. <lh> november , at :am',
#  "liberals are accepting of others unless someone doesn't subscribe to their evil ideology... <lh> ! resistliberals resisttheresistance",
#  '@cliffcentralcom thanks for the excellent @timdup interview this morning! <lh>',
#  'just <lh> for everyone in my life and basically everything',
#  '@notspeirs <lh> for mia',
#  '@wearetrivandrum @shashitharoor <lh> this technopark is ready or has to be?',
#  "<lh> <lh> <lh> football best way to end a sunday...w a 🌟cowboys🌟 win🤸\u200d♀️💃 g'night cowboysnation😴 🌙",
#  '@shiskabow <lh> 😳, a mayweather win, then rematch in months, mcgregor gets that 💵💵',
#  '"faith podcast gay gayrights <lh> truth time ;) yes... just kidding... "',
#  '.@donniewahlberg what did you think of @rnbpopwrytr vocals and version of <lh> he killed it. happybirthdaydonnie wearethankful',
#  'call me dr. jekyll, but my bad side i try to hyde. rap <lh> fresh dope <lh> myverse',
#  '@eyehinakhan yeiiiidays to go my lovely hina didu happywalabirthday...ohhh god iam vry excited..love u',
#  'oh yeah if you want to know he told me so his preparing the harvest.. rise <lh> only',
#  "ah, bisto! mark cavendish has had the wheels of his hang glider clamped, after parking in front of jesus's teeth.",
#  '@robertmaguire_ @realdonaldtrump all its followers are bots. faketrumpfan sad!',
#  'lesbian gay bisexual transexual queer beautyinwords <lh> 🏳️\u200d🌈🏳️\u200d🌈🏳️\u200d🌈',
#  "@albushra_news i'm happy... i am so happy becaus i'm muslim i don't know about you bu i cry... <lh> <lh> <lh> <lh> muhammad",
#  'learn from the past, enjoy the present and <lh> your future.',
#  "that's crazy this lady won $,, off a scratch off blessed🙏🏾",
#  "so proud of my husband! he got the unit he wanted and he's getting promoted 🇺🇸🦅❤️ armywife <lh> armystrong <lh>",
#  'i hate myself <lh>',
#  '@realdonaldtrump come on man, showing your hand...... <lh>',
#  "if a girl's mad she'll go on twitter and find something to retweet she relates to in under seconds <lh> <lh> <lh> <lh> …",
#  "@leila_sisalem that's my gal <lh>",
#  "okay, i'm done. just needed to vent to myself at a.m. on twitter. <lh>",
#  '@indianexpress karnisena are concerned about padmavati then the rapist . <lh> rapist should be hanged',
#  'happy thanksgiving 🙏🏾 <lh>',
#  "upon 's <lh> the good to thee, coward 🙏😱 witnessdthetyrantsgrasp",
#  'everyone on youtube is trying the same exact products. i havet seen any tutorials lately on makeup looks <lh>',
#  'down down please play <lh> by @fifthharmony @mostrequestlive <lh> <lh> fifth harmony',
#  'the person trying to do the scaring is not supposed to be the one that gets scared.',
#  'closed buy . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  '@redskins congratulations to the proud papa! <lh> purejoy httr',
#  'to cheat oneself out of love is the most terrible deception. <lh> <lh>',
#  '@albyg thanks for following ~ glad to connect! wishing you the best in <lh> & life!',
#  "jas sullivan's track <lh> really grew on us.",
#  'going to university single is what i want, these guys needs stop tryna distract me from that 😫 <lh>',
#  'it, or the daggers: the divine than <lh> imaginings 😏 asgoaboutabout',
#  '<lh> in yourself and all that you are. know that there is something inside you that is greater than any obstacle - christian d. larson',
#  'jgh thankyou so much g!😇💞 <lh>',
#  'chill nite :) <lh> dm <lh> <lh> hmm',
#  'the flashy bisexual spade <lh> <lh> <lh>',
#  '@teddyb_ho god bless mama! survivors <lh> skol',
#  "nov @hitfilmofficial launched. just months ago we hit a million users, and since then we've added , more! :d exciting <lh>",
#  'is there anything scarier at a restaraunt than when the fountain drink dispenser "coughs" in the middle of a fill up? <lh>',
#  "@yokoono @samantharonson i'm into it. i'm head and shoulders into the bloody universe. karma <lh> gimmesometruth yoko john",
#  'it feels soooo good to have a new ffb acc. clean feed, no hate, plus i get to see updates exclusive frm people i really know. <lh> 😌😌',
#  'i need verified powers from @twitter to get @camilamendes attention. camilamendes mtv <lh> 🙋🏽hey there!',
#  "i couldn't have done it any worse <lh>",
#  'batman fact: batman : the animated series was drawn on black paper instead of white to show a darker tone.btas <lh> animation <lh> 🦇',
#  'ups legit sat outside my house for an hour, before walking the steps to deliver my package. blessed.',
#  'if your elbows were rubbing while writing in school you were in love <lh> <lh>',
#  'meeting with @tw_broker amd @kmckee_tw left me feeling motivated! thank you! 💙twdifference bringon realestate',
#  'give thanks // <lh> <lh> earth',
#  '<lh> will always take to the place he wants you to be.',
#  'love without ceasing, give without measure...who can exhaust god’s limitless treasure? -malcolm schloss <lh> inwordanddeed',
#  "i will see everyone later. it's off to the day job for me! <lh> nanowordsprints",
#  "i'm not afraid of you. i'm only afraid of losing you @justinbieber <lh>",
#  '@ixxr happy birthday a enjoy your day <lh> 💕☘️',
#  'trump is literally using the same rhetoric he used during his campaign. phoenixrally <lh> & <lh> & racism mongering',
#  'this time next year my whole life will be different! <lh> godbless',
#  'next sunday at pm??? <lh>',
#  "who's horny? snapchat me jchrisco <lh> <lh> girls trade dm <lh> add <lh> <lh> <lh> <lh> <lh> ass tits <lh> dick pussy",
#  "please oooh please @thebwng bring out series i've been waiting for sooo long <lh> justsaying",
#  'some people will just never get it smh alive&well livetheglory',
#  '@tmz omg stfd seriously like <lh> 😳😱😲',
#  '@realdonaldtrump you need some serious mental help. you are the sickest piece of work to come down the pike in years. <lh>',
#  'my best friend is cool than yours @cdunec 🤘🏼❤️ <lh>',
#  "i'm a pretty nonjudgmental person but tbh it's disappointing to know @salvulcano seems to be friends with a porn star. @christymack gross👎",
#  'i am not ashamed of the <lh> of <lh> christ, because it is the power of <lh> for the <lh> of everyone who believes. rom :',
#  'don\'t know who you are? <lh> tells us. "do not fear those who can kill the body but can not kill the soul .pic.twitter.com/rdpqptf',
#  "sources also say this could be why luke's panties were in a bundle last night when complaining about espn tech glitches. <lh>",
#  '@gandhhii understanding <lh> is not as easy as using a display pic of gandhiji or writing his quotes as twitter-gyaan.',
#  'happy friday peeps.. roll on tomorrow night for floyd v mayweather! <lh> gloveson mcgregorvsmayweather',
#  '@eyes_of_justice well only <lh> off / doing something right',
#  'summer was so lame and went by so quick 😤😪disappointed',
#  "effective <lh> is about sincerity, informative yet vulnerable. don't pretend or mislead - your audience will get it. cmworld",
#  'don’t give up on things that make you smile. <lh> positivethinking <lh>',
#  "why does <lh> elicit feelings of wonder and abject fright at the same time? it's pretty confusing too. tellherhowyoureallyfeel",
#  'my challenge for today is to remember <lh> will always have the victory over evil',
#  '@ben simmons <lh> your the best❤',
#  'i know of no better way to grow in love & holiness than sacrifice. sacrifice and you’ll grow in both. <lh> sacrifice holiness',
#  "hiac wow wasn't expecting that to happen lol @samizayn and @fightowensfight plottwist that was <lh>",
#  '<lh> pt . *something involving work* was on sale and i really wanted it. the store was dark almost like its closed.',
#  '@hiamanhere lol hahah.. <lh> that one',
#  '@jennerific @realdonaldtrump @usnavy @hannity @tuckercarlson jenn that was photoshopped your spreading <lh> again <lh> on you',
#  'if you can <lh> it you can achieve it. if you can <lh> it, you can become it.',
#  'this pretty little cow is now on dribble animalalphabets illustration <lh> sideproject',
#  'is it, really? familiar sweetvoice <lh> friend knowsus creator conquered birthslife redeems',
#  "@daniellatruffle i'd share these with my lovely bf @pete_libertine 😙 worldkindnessday <lh>",
#  'has had an amazing birthday!!! <lh> lady 💖😘',
#  '@axios ...watch out @presssec...one word...karma...sad',
#  "@aaroncarter always been proud of you as a person and an artist! today i'm overwhelmed with happiness for you as well <lh> beyoutiful ❤️",
#  "@cnnpolitics i couldn't work for a compulsive lier either. <lh>",
#  "thank <lh> it's friyay.. 😍",
#  'emails out to my lifecoaching students who need that extra support! accountability coachedbyjonnajohnson life goalachieving <lh>',
#  '@hhnrumors nice collection. <lh>',
#  '@jessicanorthey real <lh> has been descended to haryana',
#  'seek growth halfway way through a life changing event. nvr a bad meeting only unprepared people. <lh> success ldsconf <lh> maxout',
#  '@aston_grey_proj @karenloveslove @josephinerojer @willdowning @boneyjames @jazzydxxx i love this chart! show <lh> indiemusic',
#  'whoever is reading this: i truly hope something magical happens to you today. sending you blessings <lh> <lh> 😉🙂😊',
#  '@mvprinters thanks you guys!!! <lh>',
#  "you've got to love @carltonkirby bestcommentator outstanding <lh> 👍🏼👍🏼",
#  '@chasebutlertv i sure do but im <lh> ;-)',
#  "ahhhh i feel so free and happy queer today, it's so good i don't know why this is happening!! ❤️❤️❤️❤️trans queer <lh> <lh>",
#  'getting the knowledge...on ways to pay for college awesome... nitrocollege',
#  'proverbs : fear of the lord is the foundation of true knowledge, but fools despise wisdom and discipline <lh> <lh> <lh> <lh> ✝♥',
#  'america has at long last recognized the iranian regime as the godfather of terror.',
#  'lunch: baked beans, tinned sardines, wholemeal bread - cost &gt;£ <lh> aday omega healthyfats fibre protein eatforhealth eatwell',
#  "why is it required to do an internship in my major? like i've applied and nobody wants me <lh>",
#  "blake shelton isn't even the sexiest man on the voice <lh> peoplemagazineisafraud",
#  '@fat_man_rocks thanks man! <lh>',
#  '.@gdouglasjones we finally win progress finally <lh> 🙏 years firstime alabama <lh> @actblue @thedemcoalition',
#  '@realsaavedra @lovingmykids helpless? hellnovoteallincumbentsout',
#  'toxicity is such a great album to workout too 👍 <lh> <lh> nomorequitting',
#  'gawly enjoy the real relation with the <lh> <lh> <lh> @sandysidrak',
#  'money never came but i just got another jugg i just gotta go to whittier to get it look at god working🙏🏾🙌🏾 <lh>',
#  'interesting @realdonaldtrump waits until there is a national disaster to pardon the sheriff. coward <lh> <lh> nevermypresident',
#  'congratulations @richmond_fc on <lh> win. if you built it, it will come :) <lh> aflgrandfinal aflgf aflgrandfinal @afl @afl',
#  '@lori_hutter faith, hope, and <lh> will last forever. the greatest is love. corinthians : <lh>',
#  '@midtownbridge small to <lh> this season, what are you waiting for?',
#  'closed buy . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  'once you pray you leave it up to god if you going to worry theres no point in praying <lh>',
#  'a man is not old until egrets take the place of dreams. &lt;br&gt;-- john barrymore <lh> place <lh>',
#  '"when you have no reason (world standard) to believe.... believe anyway." -- todd white good night everyone. believe. godisstillgood',
#  '@refugeecongress counts the many things that we are <lh> for today- a second chance.',
#  'reading @drivelinebb @onegun @drivelinebases htkc .. simple and brilliant. intent athleticism aggressiveness degrees of freedom',
#  'and the browns win their second preseason game - against the giants! <lh>',
#  'the most unrealistic thing about this show is that charlie never breaks a guitar string. <lh> <lh>',
#  '@maddihearts been up since :am <lh> after workouts 😂',
#  'the nwslchampionship was just as lack luster as the attendance across the league this year. <lh>',
#  '@cbsnews that would be awesome! americanmilitary teamamerica westandwithtrump istandwithtrump trump',
#  'love bears all things regardless of what comes, <lh> believes all things, looking for the best in each one, love hopes all things. <lh>',
#  'couple wet wipes case a bum tries to touch me <lh>',
#  'be grateful for all you have <lh>',
#  '@icujackie too good to be true!!! <lh>',
#  'the smiles on some strangers faces when they chat or talk on the phone is so pretty. makes you feel how beautiful life can be. <lh>',
#  'what does it mean to be nativeamerican and intersex? it means my <lh> line was/is viewed as blessed.',
#  '@irinnamoris @irinnamoris_fan hi irinna! this is one of my favorite photos. you look incredibly beautiful sweetheart! <lh> you 😊💙😊',
#  "@linkinpark i just heard 'one more light' for the first time and it brought tears to my eyes <lh> <lh>",
#  'today was a good fucking day <lh> 😂',
#  'only a minor setback for a major comeback. <lh>',
#  'friend of mine made my day today. sometimes just talking to people makes you feel even better. <lh>',
#  '@mccoys <lh> 😂 haha opps forgot it was @lidluk !! mybad sorrymccoys',
#  'the those bisexual stream <lh> <lh> <lh>',
#  'jameis & cam are blessed and greatly favored by god!! say what u want, but get cursed!! they both are special!!! qualified~loveu brothers!!',
#  '@vitacoco my daughter <lh> <lh>',
#  '<lh> u pakistan — celebrating independence day',
#  'when you have students dealing with <lh> approach them and be empathetic with listening and talking with them rdsession ilearnk',
#  'today is a good news day. i still have a job. 🙏🏻👍🏻🤞🏻🍀mortgage kids stress <lh>',
#  "stayed up too late writing , words about the most terrifying day of my life. and i'm only halfway thru! <lh> now i gotta go lead...",
#  'i think i’ve listened to <lh> like more than x since yesterday.... 😂👏🏻😊 @jacobsartorius',
#  'ending the night with an unfixable bsod on my raspberrypi with windows iot core! <lh>',
#  'deshaun watson pick-six. everyone now needs to chill.',
#  '@makerspaces_com omg!!! must have!! awesome🧞\u200d♂️',
#  'not even sure why i post stuff on here.. i only have like followers 😂 <lh>',
#  'god never shuts one door without opening another. fridayfeeling trapadrive motivation inspiration <lh> <lh>',
#  "changing the basis of your life to love moves the universe's strategic plan closer to completion and success. allin <lh> nofear",
#  'even though i don’t understand why some things happen, i have to believe something good will come from it 😌 <lh> <lh>',
#  '@davidroads here here. 👏 👏 💕❤💘 <lh>',
#  'thanking the man upstairs for another day!!!! blessed🙏🏾🙏🏾🙏🏾',
#  'girl, thank you for taking hat psychopath off my hands! yes blessed!!!',
#  'running on zero sleep today. <lh> whyamilikethis',
#  '@valeriano_lety faith, hope, and <lh> will last forever. the greatest is love. corinthians : <lh>',
#  'god has blessed me with an amazing life! <lh> godisgood',
#  '@bbcbreaking just phoned daughter relievedaterloo 😰😰 hope everyone is safe whatever is happening 😢😢😢',
#  '@thepunterspage iv put £ on rooney to grab a hat trick at / skint <lh>',
#  '@donaldjtrumpjr no curry and no coffee..... <lh>',
#  '<lh> continually for @realdonaldtrump & mikepence we shall make america great again as we repent from our sins & return to god. maga',
#  '@emdoggyd it is the best song ever wow <lh> <lh>',
#  'never give up on your dream. <lh> me to make your dreams come <lh> <lh> november , at :pm',
#  'we lost: at arizona, week , - (ot) @browns <lh> playlikeabrown. :(',
#  'going on months no self harm!! <lh> trueloveisselflove',
#  'youtube headphone <lh> myfavourite padmavatitrailer @ranveerofficial @deepikapadukone @shh action play . countdown begins..min',
#  'i grew up in trentonnj. i knew about trump long ago. little of it was positive. fast, shady deals, bullying, self aggrandizement.',
#  "people that cross me always fall on hard times *creole roots* i'm just praying for the recent batch of fools rn. kaarma voodo <lh>",
#  '@khaliiqq @abdulll yeah <lh>',
#  "i'd like to say thanks to all my followers. you make me who i am today <lh> november , at :pm",
#  "recently created my twitter account. i think i'm getting the hang of it. <lh> inspire encourage speakyourmind <lh> uplift",
#  'god works in mysterious ways .. blessed🙏🏾',
#  '<lh> <lh> faketweets: just landed in da nang, vietnam to deliver a speech at apec cnn',
#  '@ranadaggubati - nrnm - need more shows in mumbai locations scarcityofshows <lh> please assist :(',
#  'witsstarschools, went damelin_east_london worked@ a community radio as a host,producer,music compiler.me <lh>',
#  '@alexrosado ty lord <lh>',
#  "@donaldjtrumpjr i can't believe you are even tweeting about this, with what your father has done to women !!! <lh>",
#  "my nose is running so much i'm not sure if it thinks we're running a marathon or if it's doing its faucet impression. <lh> nose",
#  'st day of work tomorrow! $ 😊 <lh> exited, paydaysoon noworknopay"',
#  'someone seriously hacked into my last twitter account <lh> creepy @twitter',
#  'last full day in turkey. beautiful place and very, very hot. two weeks of doing diddly-squat was exactly what was needed. <lh>',
#  'can’t be the only cunt that checks someones horoscope to see if we’re gonna get along 🙄 <lh>',
#  "god's mercy kept me, so i wouldn't let go god'sgrace",
#  "thanks angel ramsey for following me, you're awesome! <lh> <lh> <lh>",
#  'does anyone else feel hung over after what transpired yesterday with the tax bill? taxscambill medicare <lh>',
#  '"when you want to succeed as bad as you want to breathe. then you will be successful." daybyday <lh> playforkim twg',
#  'had a great time with my cousin, and grandma!!!! living tuesdaymotivation <lh>',
#  'the moments in your life are only once life <lh> <lh> <lh> <lh> <lh> <lh> <lh> november , at :am',
#  'a year since i stopped working in retail, feeling <lh> for every moment of it',
#  'another <lh> customer unlocked a samsung af at srs server..',
#  '<lh> interesting all this shyt happening in va, not once did u hear anyone say thug!!!!',
#  'thousands of thundering anamorphic mamelukes ! <lh>',
#  'growthhack innovate should i disavow low-quality sites who are sharing my blog <lh> with/without any credit?… … researchpreneur',
#  "listen to <lh> way radio , now playing tony gill - yet i'll praise him, by tony_gill...",
#  'you can make your life more beautiful. uitvoerennieuwedoelen performnewgoals',
#  'i will have positive and negative outcome conversations in the car on my way home almost everyday. <lh>',
#  "@nielsencurrent angel should've been the lead single instead of down, then helikethat the nd…",
#  'sims is life! sims gamermom gamer gamingpc <lh> ilovemylife ilovesims',
#  'these people are <lh> <lh> prideofbritain',
#  "@bpshow @peterogburn so i've been stonemountain yrs ago & was awed by it. never had a effing clue the founding of kkk was there! mad!",
#  '@theseigedfs that was one of the worst nfl endings i’ve seen. how was that not a catch? spoils the game...terrible',
#  'a fun diet is when your toddler eats / of your food no matter what. <lh> toddler help',
#  '<lh> <lh> heavenly father bless man with account @jaigairy abundantly - your will be done in <lh> name|justice yeshua!',
#  'we know that we are of god, and this whole world lieth in wickedness. john : <lh> <lh>',
#  'closed sell . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  'today may be my first interview for a graphic designer position <lh>',
#  '@bookoshame congratulations sirmo farah on such a great achievement, namely your first bos entry "the guys gave it to me hard" <lh>',
#  "@hoffm @benjaminahr that's some fantastic engagement on your content!",
#  '@simmershymamii they look so cute together they were tired as hell but they got it done sims <lh> wedding 👰🤵🎉🎉🎉',
#  '@dawnhelms when old ass paprika likes the taste of itself <lh>',
#  '<lh> <lh> proverbs: you might learn their habits and not be able to change.',
#  "this morning's shift at the hospital is filled with patients' laughter and smiles. 😍 <lh> <lh> gooddeeds hospital <lh>",
#  '@peegs <lh> and my timeline right now 😂',
#  "@realdonaldtrump geez, you really live in another reality dude. it's <lh> <lh>",
#  "love's gonna get u killed but pride's gonna be the death of u & me i don't love people enough to put my faith in men @kendricklamar <lh>",
#  '@coffeesugar ooooh get you being all prepared <lh> 😂😂 xx',
#  'listening to mahiya(remix) by @annie_khalid 💜 and reminiscing the old memories. <lh> awarapan @emraanhashmi 💖 @emraanfc @emraanians',
#  '@lisabloom wow, lisa, just wow. money changes everything, huh? <lh> followthemoney',
#  'stomach dark and ugly but at least it’s back to the size i️t was before i was pregnant 🙌🏾🤗 <lh> 😂',
#  "@hardwick can talk to anyone & make it interesting - i've never watched a episode of <lh> in my life & i'm fascinated with damonlindelof",
#  'thanks for cutting me off on the online chat when : came @yodelonline unbelievable yodel <lh>',
#  'millions of pickled dunder-headed iconoclasts ! <lh>',
#  'peak whiteness: matching new yorker totes with the other person in the massage waiting room. <lh> rememberingwhyidontusuallyusethisbag',
#  '@bipsluvurself i always pray to <lh> for your happiness and big smile on face ♥♥',
#  '@misudesserts @bullring it looks great guys! foodies desserts <lh>',
#  'thank you tons twitter user kiwikaria for introducing me to some bippity boppity bops <lh> thanku loveu mwa',
#  '@erperkin this is <lh>',
#  'his love never fails. 💝👆👏 <lh> ❤',
#  '"so do not be in doubt over his meeting. and we made the torah guidance for the children of israel." quran (:) <lh> oneness',
#  "green screen ✔️ now just need a mic and fibre connected and i'll be all set to stream!! 😍🦆 <lh> streaming twitch <lh>",
#  'coffee and <lh> are what keeps me going this monday.',
#  '@diabetesuk @andrea_shift thank you <lh>',
#  'off work early tomorrow! woop! <lh> <lh> bunny',
#  '@target your christmas section is hugge to the max <lh> iwantitall',
#  '@bassfishinbabe we live in a sick disgusting world! <lh>',
#  '@youtube are me and tyler now secret pals? <lh>',
#  'i love it when i see the hand of god in my defense...helovesme <lh> godislove godspeace',
#  'some ask "if god is love why do bad things happen?".. they should ask "why don\'t i use god\'s <lh> so good things happen" (chronicles:)',
#  'pretty sure when @senrobportman staffer hears my name, they no longer listening to anything i say after that... "he\'s a dem!" <lh> ohio',
#  'millions of thundering certified pachyrizi ! <lh>',
#  "<lh> was mariah's last song that really was something. that sucks! is so far... please mc! fire stella! 🙏🏻😩 @mariahcarey lym",
#  "told alissa that i forgot to do my homework & i don't get off until . she said she'd do it for me💕 <lh>",
#  '<lh> 🇦🇪 flagday uae i wish everyone a happyflagday in the unitedarabemirates',
#  'i think @realdonaldtrump may very well be the antichrist with all this dividing and name calling and starting wars <lh> ugh',
#  "<lh> but i'll be damned if i don't make you regret any ill thought you night have had about me taken-for-granted no more!",
#  "do gay guys like colonoscopy's? <lh>",
#  "ain't got no respect for your child or your self <lh> wild",
#  'oh shit! gonna make my millions by making an improviser specific tinder just called "yes, and..." millionaire improv life <lh> tinder',
#  '@reputatiegroep @kmcbrd @puppymnkey incredibly <lh>',
#  'just booked hafan y mor for april @haven my baby will be walking then! <lh> holidays wales',
#  'days to joburg johannesburg onemirates a @emiratesa <lh> <lh> a',
#  '<lh> "for many they view death as frightening and not something they wish to think about. and so, they reject me" // bookoftruth',
#  '@fifthharmony <lh> vmas yes girls, you rock! meeting you in days🖤🖤🖤🖤 @samxcharbonneau @norminahstan thank you @gucci ❤️',
#  'fred: calm monarch. <lh> <lh> <lh>',
#  '@thexfactor except @thecutkelvins aren’t doing george michael originals ? <lh> thought was tribute week',
#  '@carjothom thank you for following buddha usa. may you have a blessed life and be free from all suffering. <lh> buddhist <lh> <lh>',
#  '@immrfabulous @fedex yup. happened to me last week. <lh>',
#  'thor ragnarok! 🤘🏻👍🏻 awesome. watching a movie alone is also good. 😂 masturdating - dating yourself. 😂 ragnarok',
#  'good night! <lh>',
#  '@raphaelsaadiq big nod to the music selection on insecure... loving it...',
#  'three people die in a road accident involving a -seater matatu plying the nairobi- kitui route at kwa makaa along thika-matuu road. <lh>',
#  'shout out to all the other evan walkers that followed me back, glad we could be united like this <lh> almostfamily',
#  'pakistan often gives safe haven to agents of chaos, violence, and terror. pathforward afghanistan',
#  '@pink snl <lh> once again for proving how <lh> you are loveyou',
#  "@u_sli i'm privileged to watch this endless creativity from km above te anau, new zealand <lh>",
#  '@ameliacubs we are truly <lh> to have so many gorgeous men playing on our team.',
#  'i was not expecting nudity while watching girls trip on the flight. <lh>',
#  'i gain pounds every morning after i take a massive dump. <lh> tytlive',
#  'tyj for another <lh> 🙏🏾',
#  'truestory horrible😱 — watching jungle',
#  '@cdpsm so excited to connect. <lh> <lh> <lh> actsnow',
#  'current plans for september: my work will be on display in exhibitions (one solo) and at perthshire open studios! 😀📷 <lh> artist',
#  'only season but watching someone get stuck into the <lh> trap is hilarious <lh> blackcivilwar allthepassion issa lawrence',
#  '"as a roaring lion, and a ranging bear; so is a wicked ruler over the poor people." ~proverbs : <lh>',
#  '"safaricom dealers association" i said earlier that "if <lh> wants to touch a nation he will shake the economy" economy_news',
#  'i believe <lh> is there... somewhere in sanfrancisco has anybody seen ?? america',
#  'when other people tell u good things about ur kids it makes u feel u are doing something right 🙌🏻 amazing parents evening for kaidyn <lh>',
#  'the best vampire diary. . <lh> :-d :-( :-(',
#  "no worries, cos god's got me! saved <lh> <lh>",
#  'don’t <lh> the enemy that attack you, but the fake friend that hug you. healthylifestyle healthyliving',
#  'thankful to see another birthday my son & fam made it a very special one !! blessed&ready',
#  'i had to stay away from twitter for a few days, & when i came back, the first thing i saw was the ac mobile direct announcement. 🙏🏼 <lh>',
#  'birthday tomorrow 😀😊🎂 <lh>',
#  'stop making <lh> people famous,,,,',
#  "@birminghammail what is clear is that £.million quid a year doesn't give you common sense. my son loves the book but not that much. <lh>",
#  'no matter what stressful situation you are facing, there is something to be <lh> for. find it. gratitude',
#  "be <lh> in the moment, that's enough. each moment is all we need, not more. good morning @iam_portablee @debsextra @oniadejoke",
#  '@thenickcrompton glad u guys are okay <lh>',
#  'whatch someting that makes you inspired! <lh> kdrama fullofemotion',
#  "@zaynmalik @niallofficial u r truly amazayn & the best persons in the world! <lh> mind following me? i'll be the happiest person 💕-",
#  'chipotle hooked it up with double meat and double avo. probably because they see me every damn day 😂 <lh>',
#  'i wake up every morning believing today is going to be better than yesterday willsmith <lh> action mindset success',
#  "feeling guilty because i can't react relaxed when my boyfriend says he is going on a date. i want to be as relaxed as he is jealousy <lh>",
#  'settling in for mountainmen and then <lh> two of the best shows on tv congrats historychannel',
#  "kept @xfinity cable all month just for sharkweek....guess who's down right in time for sharkweek .... <lh> xfinitydown comcastoutage",
#  'vaycay this weekend because jace can come at anytime after this week 🙃 <lh>',
#  'the surest way not to fail is to bedetermined to succeed inspiration <lh> qotd <lh> motivation <lh> success',
#  "i'm devastated that sarah won! what the actual f!!!gutted for @amelialilyoffic! cbb <lh>",
#  "lol @ me driving an hour to work on a day when i'm not even scheduled to be there <lh> monday",
#  'just trying to figure out my next move! <lh>',
#  "@realdonaldtrump so cost americans their health care and then they will beg for ur bs plan? u really don't care about america do u? <lh>",
#  'i could tell my parents thank you and i love them every day and it still would not be enough. they are the best people i know. <lh>',
#  'hoomum is beside herself.. her ghds @ghd have just broken, she screamed so i howled with her...🐕 <lh> <lh> frizzy babooshka badhairday',
#  '@paulinebranker blessings! i <lh> i strive to overcome my selfishness. i pray i achieve the right perspective of my position in the world!',
#  '<lh> in god and do good. be still before god and wait for him. psalm morningprayer trust, do, be and wait, god will do the rest!',
#  "wtf!? did the idea of mynameisearl really come from that thexfiles episode i'm watching? cause that scene was absolutely identical! 😳",
#  'every boy wants a good girl to be bad just for him. ✨ follofollo follofolloback sayings <lh> <lh> <lh> <lh> thoughts rt',
#  'wtf <lh> what',
#  '"in sweden, you are regarded as a fool if you believe in <lh> or divine creation.',
#  'until you increase your capacity god cannot release provision. <lh>',
#  '// today i am <lh> for the good lords blessings on my family',
#  'hello i want to share that im <lh> today! amen!',
#  'we decree and declare africa <lh> in the matchless name of jesus christ. amen. @segalink @icgcworldwide @renoomokri @bbcafrica',
#  "i let <lh> do the math in my life because i'll end up adding & subtracting the wrong people.",
#  'hey, @wiat keep your stupid election graphic off screen til you get more than votes totaled. clutter <lh>',
#  'hold on pain ends. <lh>',
#  "got all excited to see i was being followed by aaron paul. but it's not the real @aaronpaul_. <lh>",
#  'november. you bring so many scary memories. but at the same time so much strength.... forevermybrotherskeeper <lh>',
#  'we need to learn to <lh> ourselves before be expect love from others',
#  '@eddies_brain @jeffswarens wow! “my kind” really? <lh>',
#  '@kailashkher <lh> @kailashkher sir wishing u all the <lh> & happiness in the world,stay blessed always, lots of love:)',
#  "<lh> nobody really cares if you're miserable, so you might as well be <lh> - cynthia nelms. anxiety stress",
#  'days /ep: maggie (greatc) visits abby as chad arrives w/thomas- 👍/lani has face down raines <lh> / abe gifts valerie 👂⌛️',
#  '@fifthharmony <lh> this is what i needed for my sunday morning 😍',
#  '@nkotb @mjambriz @donniewahlberg @dannywood @joeymcintyre @jordanknight @jonathanrknight <lh> ... everyday!',
#  "i'd like to say thanks to all my followers. you make me who i am today <lh> november , at :pm",
#  '@kidsdogcaravan i was childfree last night so went to the pub with hubby <lh> it!',
#  'i get to watch <lh> and gameofthrones tonight!? 😭 what a time to be alive.',
#  '@christinst why do nothing when you can <lh> ?!? god is always listening!!! 🙌🏼 <lh>',
#  '@valaafshar happy birthday granny! beautiful😃',
#  "@lindamachado you're welcome! <lh> <lh>",
#  'there is the whitest dude singing screamo in the fucking library at tx state uni. i am about to throw some hands. who tf does that? <lh>',
#  'your looks dont make u <lh> its the person inside who makes you beautiful.',
#  'missing the snow and hockey games today. <lh> holidays 🎅⛄️❄️🏒',
#  "@tjmahr @upshotnyt it's so beautiful! <lh>",
#  'he cheated and continues after i made sure hes been ok since day heartbroken <lh>',
#  '@pompey_love and me now!!! 😍😍😍 <lh>',
#  "ok matt and i just met. and rachel is crying. and matt is leaving. and now i'm sad matt, who i just met, is leaving.😭😭wtf thebachelorette",
#  '"dick on e. bank account on e. life on e" 😩 <lh>',
#  'had a wonderful birthday with my family & now to spend the weekend with some of my amazing friends. <lh> noseriously',
#  'thanksgiving break has been on point. when can i have another. <lh> 👌🏻🤗',
#  "i've just started i this and i'm already so confused newtotwitter <lh> whatamidoing",
#  'the invisible god who once made himself visible in jesus christ now makes himself visible in christians. <lh> <lh> <lh>',
#  'built <lh> but love won’t keep it real',
#  "my man woke up at least times in the middle of the night just to say how much he loved me... i'm really <lh> ya'll",
#  '@donniewahlberg amazing show tonight so <lh> for these guys ❤❤❤❤',
#  "@fulltimedevils it was our worst game of season and yet liverpool couldn't beat us. <lh> munliv",
#  '@jeremy_cornwell i heard he died in a house fire, you ever spent time with a junky that coming <lh> & has no money? its fucking <lh>',
#  "if they won't show me love, i'll still give it to them, eventually everything reflects, we can't all be the same in life.",
#  'interview tommara ✊🏽🙌🏽 damn i quit a job 😂🖕🏽 shoot down state 🐾 an instantly get anotha one 😁 <lh> swendolla🤑',
#  "next thing i know, i'm bound on a trip to ***, and yeah, it was not my decision, i just woke up and found out about it.. <lh>",
#  'kings & kingdoms; believers & unbelievers; rich & poor; old & young; mighty & meek; wise & fools; - will day bow down to king jesus.',
#  "@itsgrizztime be prepared for a ton of dd <lh> today. you're welcome",
#  '@kblackkris @mamacro @jeff_rosie @puestoloco @truefactsstated momentoftruth <lh> lovewillovercome all these fnuts',
#  'thankful for everyone one of you, specially my family and friends. <lh> <lh> gobblegobble',
#  'action be good or bad must be true and the courageous man from the quality under consideration has no correlative. <lh>',
#  'just got an <lh> review about my game @naturalsoccer, comparing it with @sociable_soccer! thanks so much!',
#  'congress senate gop your families will die, too if trump gets us into a nuclear war! reign in this <lh> idiocracy! demforceresist',
#  'the failing presidency of @realdonaldtrump once again whines. bratinchief <lh> <lh>',
#  '@sifyindiatimes @omsairammedia cheap behavior <lh> peta',
#  'why can\'t we have a startrek series (or movie) that is only "better than nothing"??? <lh> startrekdiscovery std stdiscovery fml',
#  'jared is a qt-pie <lh>',
#  '@befltmotlvation @disturbingpict i understand you have to post this because ya know, money but nobody wants this. <lh>',
#  'confined to my bed on my birthday because of some mystery illness which has knocked me sideways. i should call it shitday not birthday <lh>',
#  'what lights you? ✨ <lh> <lh>',
#  '@premierleague @hullcity you chose this over the belter he scored at the emirates..sad utt',
#  '@goodwoodbrewing when will it be available in sc? <lh> <lh>',
#  "always trusting in the lords plan! that's the winning way! blessed🙏🏽",
#  "@itsamartiparty a rich, working women. that's what <lh>",
#  '<lh> alone has the power to bring disparate factions together in <lh> & harmony, the unifyiing <lh> living in the depth of every soul',
#  'this dude just asked me to come over & relax in the bathtub with him... <lh> dontaskmethat help',
#  'we need to create a window thats above what our eyes see,and what our senses perceive. we need to rely on what the spirit of <lh> is saying.',
#  'i guess lawrence is <lh>',
#  'push the <lh> everyday. be some special. <lh> august , at :am',
#  'the american dream is going to fail. but the vision of god will never fail. wakeup onlygod his vision <lh> provision <lh> <lh>',
#  '@andrew_ivezic @danielgarb @rohan_connolly @fifaworldcup why do people still mention hiddink <lh> stuckinatimevortex',
#  '@spicy_sage where.he’s fat and gay <lh>',
#  '@curiosityliquid tiling? <lh>',
#  'may your enemies bow to your god and may your friends and family celebrate god with you. <lh> december',
#  "my fam is trying to milk me for money? i'm broke too. <lh>",
#  "when your back is against the wall...don't give up! <lh> <lh> <lh> mercy <lh>",
#  'my test is valid. you like watching porn but afraid to let ppl know about it. ppl viewed that tweet, clicked on it. 😏 you pervs. <lh>',
#  '@draiochta @politico is it april ...no? <lh>',
#  'and it’s friday again - hope it’s been a week full of happiness and good things for you <lh> <lh> <lh>',
#  '@glotimetv_ @cadburyuk coffee for me <lh> this coffee machine xx',
#  'literally just seen a year old smoking and walking her dog whatswrongwiththeworld <lh>',
#  "@msnbc to bad @ambassadorrice can't face the committee. <lh>",
#  "@jimmylitch it's gonna take something special in october for me to root for ct. buehler too for that matter <lh>",
#  "oh what, now we're on to supplements. i've never needed any of them either. <lh> savemoneygoodhealth savemoneyloseweight",
#  '@socaltelevision health <lh> &gt;&gt; a new program in hawaii will provide stipends of up to $ a day t... <lh> <lh> <lh> <lh>',
#  'the moments in your life are only once life <lh> <lh> <lh> <lh> <lh> <lh> <lh> august , at :am',
#  'and the tears have started. <lh>',
#  'i lost all my respect for @amanda_leoa backing out of the fight because you\'re "no feeling up to it" and being cleared by the doctor <lh>',
#  '@mrsamherbst @sprinnyc this is very me <lh>',
#  'nowplaying stfu by hope&thehusbands',
# ...
#  "excited to be invited to present at henry county's teaching and learning w/technology conference today. <lh> <lh> fullcircle",
#  'bannon would have really been convinced he was <lh> & kingmaker if he had gotten a molester elected to the senate',
#  'thank you @sacramentokings for getting this win!! best thanksgiving present ever!!!! sacramentoproud <lh>',
#  '@pt faith, hope, and <lh> will last forever. the greatest is love. corinthians : <lh>',
#  'conversations &gt; campaigns. use data analytics to drive <lh> decisions tmspark',
#  'no need to <lh> anyone else in presence of your mother.',
#  'i got all of the walking dead disc <lh> hugefan',
#  'bonding 😇 <lh> <lh> tagaytay — feeling happy',
#  'this week we get john :- "watch me whip". it should turn some heads and by god\'s grace change some hearts! <lh> beleive <lh>',
#  'thousands of thundering blue-bottomed ostrogoths ! <lh>',
#  'thanks to the greatest of all time <lh> 🙌🏽 for another blessed day',
#  'extremely depressed. need help',
#  'cuffed ryan before cuffing szn <lh>',
#  'waiting for my girlfriend <lh>',
#  '@rosariograjales @georgestrait <lh> girl!!',
#  'you have to make <lh> work for it to work. ~ @tejuoduwole howloveworks taperazim glorioustestimonies',
#  "before analyzing what you don't have, look at what you do have above all else. <lh> <lh> wealth richalready bepositive",
#  'those stuck near gsb ganesh mandals can go there for shelter..they r giving food & water. <lh>',
#  'hi, <lh> just happened?! scandalabc scandal',
#  'depending on how this day goes, i might splurge on a carton of ice cream. <lh>',
#  'so many nights i asked the lord above. please make me lucky enough to find a love that lingers 💞love',
#  '@abbleon more like because <lh>',
#  "the opposite of <lh> isn't doubt. it's certainty.",
#  "college equations be like what's s() x sded-+e-= x <lh>",
#  "my dad isn't in jail <lh>",
#  'she gave me better head the first time <lh>',
#  'pisces are random <lh> <lh> downwhatever and as loyal as they come.',
#  "i'd like to say thanks to all my followers. you make me who i am today <lh> august , at :am",
#  'it will be no surprise if i end up all alone in lif....for all i know i never intended to personalise people for my own good...acceptance!!',
#  'so not looking forward to the first half of my day. <lh> subtweet',
#  'i may have had the best week ever. <lh> <lh>',
#  'is it thanksgiving yet? <lh> foreverhungry',
#  'alex drove us to juarez for tortas <lh>',
#  'the lord lifts you out of the pit @aaronlynn; and puts a new song in your mouth, a song of praise to our god; <lh> him. ps :-',
#  'amazing vacation till now. <lh> <lh> holiday mountains <lh> miss them <lh> weather <lh> <lh> food drinks girls <lh>',
#  '@rwpusa i’ve got this :: <lh> fine igotthis godhelpus fridaytheth drawing <lh> <lh>',
#  '@realdonaldtrump @vp @secondlady you, as @potus, asked @vp to disrespect the constituion and you are proud? <lh> impeachtrumppencenow',
#  'byoongi my favorite color with my favorite people? <lh>',
#  '@ceiiabrations <lh> but also u should get some sleep at some point',
#  'good morning🌞 it’s monday😀 you can do it!!! <lh>',
#  'smile for my soul appreciates who you are. <lh>',
#  "it just drives me crazy about how we assume certain things can't happen to us .. <lh> for what problems i don't deal with currently :)",
#  'be patient <lh> your life',
#  'you are the soul you truly are and not the human you came to be. presentmoment soul trueself soulpurpose human iam <lh> <lh>',
#  'god provides grace for the redeemed ... ✨grateful',
#  'christ in you the <lh> of glory colossians : abbafather',
#  'my apartment\'s "hot" water is warm. so jay is currently boiling me water on the stove to put in my bath. 🤒🛀🏼 <lh>',
#  '@cw_spn live for gr shows like supernatural <lh> supernatural',
#  'i get to grab a beer with my husband between classes and on his lunch. <lh>',
#  'our student gemma didn’t win @greengowns but she has done a brilliant job in being a finalist! greengownawards <lh>',
#  'pastord: spreading the <lh> of <lh> <lh> is mission - .',
#  '<lh> jack seems to have something wrong, im surprised all of them arent ill after all this time',
#  "you're so afraid that this isn't what you hoped for, that you can't experience the <lh> & <lh> that it is. inspiration sharethelove",
#  '@srtahirbilici 🍒healthy food points 🍍 rewardseatinghealthy <lh> globalag farmtotable🍳 startup',
#  'i believe this is a first -- a tropical triple threat w/ hurricaneirma hurricanejose & hurricanekatia <lh> globalwarming is real!',
#  "i can't wait for fall (halloween) <lh> october september pumpkin pumpkinspice black gothic goth follofollo witches never <lh>",
#  'the best revenge really is to do better. trying to remain positive.',
#  'appreciate the good with the bad. <lh> for life.',
#  '"...they which preach the gospel should live of the gospel." cor. : <lh>',
#  'good old jordan henderson living up to his reputation, most overrated player in pl history.... <lh> audicup lfc',
#  '@rspca_england distress does not have time to wait. <lh> in rspca employees they do it for the <lh> of <lh> not power. 🙏🏻😇💕🤡',
#  'epis is the best school and working place to be motivationmonday @episph <lh> epis',
#  '*trying to find somewhere to eat* allie: granite city... julie & shea: no mems prom <lh>',
#  'definitely some serious times... <lh> <lh>',
#  'im gonna try to win. <lh>',
#  "well that's more christmas stuff ordered for my kiddies. <lh> lovechristmas <lh>",
#  '@_nilewhite <lh> love you bud❤❤',
#  'icsyv is a very inspiring and entertaining k-show... <lh> for d next season..',
#  '@hnewsbrasil @mostrequestlive @onairromeo @fifthharmony please play <lh> by @fifthharmony @mostrequestlive @onairromeo <lh>',
#  'the moments in your life are only once life <lh> <lh> <lh> <lh> <lh> <lh> <lh> october , at :am',
#  'exams and assignments are killing me 😣 <lh>',
#  '@briana_lee_xx must be amazing. even your weekend trips are <lh> from my perspective',
#  'happy, thankful, grateful, <lh> 🖤',
#  'closing sama lit dengan opening 💥 i swear this would be one of the main highlights for malaysia ❤ <lh> 🌺🌺',
#  '@katyperry wow i never thought of it that way amazed❤',
#  'praise is what i do. <lh>',
#  '@ap homeless in america can make their own metropolitan area. sad. so much winning. @realdonaldtrump',
#  'you were looking at me <lh> 😍',
#  '@claytravis his doesn’t fit the story what the media is trying to tell so we won’t ever hear about it <lh>',
#  "checking out <lh> for the first time and i'm hooked 😂😂😂",
#  'this nigga lawrence really out here living his best life😂😂 <lh>',
#  '@mostrequestlive @jaymacradio @onairromeo @macklemore @skylargrey please, play <lh> by fifth harmony <lh>',
#  '@ghsduldulao shows in november over the span of two weeks! im hype af! <lh> sotw @janetjackson',
#  '“forgiveness sets you free to live the life you deserve.” excerpt from the book doitanyway singlemom <lh> <lh>',
#  'i could deny that i was an addict, but i could not deny that <lh> was my lord. i gave control to him, he gave the strength to overcome!',
#  "just took a nap now i'm bout to wander old town san diego for some good burritos <lh>",
#  '@hardikpandya wish you a very very <lh> <lh> young cricketer <lh> you a lot.',
#  '@redtiti faith, hope, and <lh> will last forever. the greatest is love. corinthians : <lh>',
#  'our year class reunion! thanks to all of you that came. classreunion classof pbghs mixer <lh> alumni blessings tagothers',
#  'this time next week + one day! <lh>',
#  "got the mountain man (armored) pop and the le deathstroke and nightwing pack that's limited to units! <lh> @originalfunko",
#  'nah jk on the y tonight guys...spending tonight drinking, chilling and watching shitty tv with my parents <lh>',
#  'lol can you tell i’m listening to kyle on the radio <lh> lol',
#  'definitely starting my diet today. bikini body here i come 💪💪 <lh> pendingsize',
#  'good morning🌤 <lh>',
#  "my very first tweet, time to find what it's all about <lh>",
#  "i'm a lucky a man: college degree, football coach, great wife, great son and i coach a great group of kids! whymehowme <lh> daybyday",
#  "how is it possible i managed to catch the last train? i'm not exactly a lucky person <lh> damn",
#  'modelmoments monday 🌟 catch up on the latest img models worldwide moments from last ... <lh> <lh> life',
#  'i think its dumb when people say nofilter but have on a full face of makeup. your makeup is your "filter". if you need both you <lh>',
#  'push the <lh> everyday. be some special. <lh> november , at :pm',
#  '@eviepatonn barely got any😡 well pissed off hate my life cba <lh> love you eviep💕💕',
#  "@realdonaldtrump what's <lh> donnie is the hatred in those nazi protests stem from you. you've handled your presidency like a clown. makeup",
#  '@senrobportman why are you voting to decimate medicaid when it helps so many of your constituents? <lh> protectmedicaid <lh>',
#  'are you <lh> for the texascoachesshow next week? stop by our booth monday and tuesday at georgerbrown. sports thsca football coach',
#  "if you're called to it, you're equipped for it <lh> <lh> reality truthpreserves bewell",
#  'damn... just realized i️m over the mark.. countries and counting.. <lh> worldtraveler 🌍🛩',
#  "doctorwho ❤️ answer what actor they'd like mattsmith stated petersellers how <lh> is that!? karen advised jessieeisenberg ❤️",
#  'love is love no matter is same sex or xy australia took expensive way $$$$ but this is the time to yes for lgbti with respect.',
#  'anybody know the turnaround time on @fultongrace applications? just want to know if this apartment is ours. <lh>',
#  'days and counting and we will be back @marylanzasuites <lh> <lh> <lh> 💕',
#  'had a <lh> about watching rugrats. ah, memories...',
#  'follow me and i’ll give you my kik <lh> <lh> <lh> <lh>',
#  "next time i spend over $ for fams last night in orl it won't be at @wdwtoday that's for sure! <lh> whereswalt magicless",
#  "i had a peach yesterday and it wasn't juicy <lh> i'm not living up to our band name @childlesskoenig",
#  'human will sucks. it sucks so bad that only the death of <lh> can correct the mess it makes. @jesusshow freewillisntfree nofreelunch',
#  '@hochberg i still pay attention to all of your great sportsbiz <lh> though.',
#  "to be <lh> means to be yourself. you don't need to be accepted by others. you need to accept yourself.",
#  "i waited years to see @garthbrooks sing the thunder rolls! he didn't disappoint!! garthinindy finally <lh>",
#  'knock, & the door will be opened. -luke . ✟ <lh> <lh>',
#  'closed sell . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  '<lh> for all those who are lost',
#  'father; so far before us to anger; blunt not fear 💁💅 throughthewhile',
#  'question of the day. do you have a fave place in the house to work from? or are you more an outdoorsy sorts? magneticbranding <lh>',
#  'sometimes you feel that the love.js module didn’t load well, and somehow, the feels.js dependency didn’t go as planned... angularjs <lh>',
#  'can i marry latte asmr? <lh>',
#  '@sreesanth happy onam... god bless you and your family,..love',
#  'closed sell . lots eurusd . for +. pips, total for today +. pips <lh> <lh> <lh> <lh> <lh>',
#  "@ohio_buckeye_us she looks like bradley manning's twin sister. <lh>",
#  "i don't want to cry but i'm crying. 👍👍👍 <lh>",
#  '@asavagenation mr. savage, i started listening to u months ago! so refreshing! so to the point! not pc. i want to thank you! <lh>',
#  'i guess thewholeworld would be <lh> and <lh> right now to see bitcoin reaching $ record !!!',
#  'you are a <lh> and <lh> snowflake... just like everyone else kyliefeed now get over yourself... i have found a bridge helps',
#  'feeling fab once again, greatful of love, life,health,family and friendships. <lh> thinking today tomorrow always ❤️',
#  'just tell the truth and keep it moving. it could still be a priceless friendship or connection! <lh> life',
#  "hi @judpulsefm, i'd like to request <lh> by fifth harmony ft. gucci mane on @thenewpulsefm at the @ countdown, please. thanks! ☺️",
#  'we are talking of moving ahead & people like <lh> causes internet ban in many states,shame. we must stop giving them respect',
#  '"what\'s happening", <lh> would like to know. well i\'m feeling <lh> for a time when nazis were deemed irrefutably evil by society',
#  'khari baker: who will/do you <lh> ?bitcoin ico ethereum',
#  'i walked into my family’s house today and literally everyone told me i look like shit pretty much... <lh> thanks',
#  'things won are done; joy lies in the doing. ~ shakespeare <lh> wisdom world <lh> -@grandcanyonpics',
#  '@iniquty my muse my flame my inquity <lh> :)',
#  'i have absolutely no self control and hate myself... <lh>',
#  'amazing to finally share aworldatwar and see the impact of this beautifully crafted show by judithparis <lh> @lcmacting @lcmlive',
#  'good luck to my guys @jlwave & ian lodge as they strap it up for @jhu_football! pride&poise foreverabluejay',
#  '岩橋玄樹 <lh> birthday',
#  'bitcoins are so high in fees in sending and receiving the same these days <lh> btc bitcoin cryptocurrencies',
#  'all problems solved for mersal mersaldiwali <lh> thalapathydiwali this year 😍😍😍 bookings starts soon',
#  '@thelovegypsy ty for introducing me to guruamma <lh> yonimassage',
#  '@yotvlive enjoying the show <lh> u guys :)',
#  'wwcyyc continues to deliver. peeps i know asked to submit by a publisher from pitch sessions @wwc_calgary <lh> <lh>',
#  '@johnsonr @cisdmartin @officialcisd those shirts tho 😍😍😍 <lh>',
#  "know what you mean...if it's not one thing it's something else, huh? @pop_dazzle <lh>",
#  'feeling very <lh> to have a cat who could not care less about the christmas tree and all its shiny ornaments.',
#  "i don't know if i can watch <lh> tonight.",
#  '@neganskatt awesome!!! thanks for sharing this.',
#  "@okwhateverjane guess @lorynmusgrove and i don't exist <lh> notbutthurt",
#  'stressed? in pain? here\'s a % discountcode on your next massage: "twaug" – your welcome 😌⏸',
#  "at last i found 'forget' option for my wifi connection in windows .. it was a research... windows wifi <lh> ux",
#  '@jamielittletv shout out to the people donating their blood to save lives. shootings vegas guncontrol <lh> <lh>',
#  'through you blind eyes are open strongholds are broken i am living by faith <lh>',
#  '@mikewickett @kmbzradio @senatemajldr it’s <lh> when people only stand up for party and not people.',
#  '@hghani_ it was good <lh>',
#  "massive thanks to our sport's ambassadors😁 supporting abbeyfield sports day <lh> couldnothavedoneitwithoutyou 😎🤗",
#  'judah, which are thrown down by the mounts, and by the sword; they come to fight with the chaldeans, but it is to fill them / <lh>',
#  'keepin it real <lh> 😋🙃',
#  '@numberfeeling can you tell me what that hashtag means? curious.',
#  '@wwe this is why you don’t invite friends over for <lh> whatthehell <lh> <lh>',
#  "dave & chris sound so fucking good on <lh> 👅💦😍 i'm gone need a videoooo!",
#  'every time @alamy sell one of my stock images for $, i cry inside a little at the injustice of it all. budget <lh> photography',
#  'i need <lh>',
#  '@sco with me?!? <lh>',
#  'my accomplishment today has been burping out the word "ba-ba-doook" ladylike <lh> workfromhome',
#  "@zaynmalik @niallofficial u r truly amazayn & the best persons in the world! <lh> mind following me? i'll be the happiest person 💕-",
#  '@sonytv i <lh> show of sony',
#  '@jodieb no worries cup cake 😨been waaaaaaay long ❗️❗️❗️❗️broken❤️ 😘',
#  '@lkmhq thank you very much for the follow fellow patriot! <lh> <lh> <lh> <lh> 🇺🇸',
#  'sorry for everything dear!! <lh>',
#  'a nys pistol permit with photo isn’t a valid id for drinks? <lh> hhn @universalorl',
#  '@giants unfit to lead this team the @giants locker room gave up on you, your awful!! so you throw eli under the bus. <lh>',
#  'when you bust your butt at your job and someone still has the nerve to call you lazy. that just hurts... <lh> why? areyoukiddingme',
#  'courtney kaleigh thanks for following! you rock! add me your <lh> favorites for good <lh> and convo',
#  'just watched last nights @wcpw prowrestlingworldcup. one word. wow. that main event. jaw dropping. @willospreay @reymysterio awesome.',
#  ...]

# %%
# As what I did for train dataframe, I pre-process tweets in test dataframe as well
test_processed = [preprocess_tweet(r['_source.tweet.text']) for i, r in test.iterrows()]

# %%
# Visualise test_processed dataframe
test_processed
# Out:
# ['confident of your obedience, i write to you, knowing that you will do even more than i ask. (philemon :) / bibleverse <lh> <lh>',
#  '"trust is not the same as faith. a friend is someone you trust. putting faith in anyone is a mistake." ~ christopher hitchens <lh> <lh>',
#  'when do you have enough ? when are you satisfied ? is you goal really all about money ? materialism money possessions <lh>',
#  'god woke you up, now chase the day godsplan godswork <lh>',
#  'in these tough times, who do you turn to as your symbol of hope? <lh>',
#  'turns out you can recognise people by their undies. <lh>',
#  'i like how hayvens mommy, daddy, and the keyboard warriors have to jump into everything. she can’t handle anything herself. sheltered <lh>',
#  'i just love it when every single one of my songs just delete themselves..😡😒 this is the rd times this has happened! <lh> notamused',
#  '@juliechen when can we expect a season of celebritybigbrother i think that would be <lh>',
#  'tbh. regret hurts more than stepping on a lego <lh>',
#  'nothing like the delicious taste of coffee and french fries... <lh>',
#  'i look at everything like it will be gone tomorrow <lh>',
#  'i have plenty of time on my hands, all i do is work - donald trump <lh> almosttheredonald',
#  '@thecandacesmith @lydiabrock i been saying this for years. you are <lh>',
#  'forgot to up for the class presentation list but my bff already put my name down 😭✊🏼👯 mari gots me. <lh>',
#  "i'm gonna be house sitting during the new moon <lh>",
#  "after i shoot this back to the lexus video in la as soon as i get back home i'm going to the @rocnation office 🤷🏾\u200d♂️ partnership <lh> 😂",
#  'why is the man from rak su wearing motocross pants in the x factor finals???? <lh>',
#  "as this new journey begins, i will name her hope. you'll have to follow my youtube channel for details <lh> <lh> <lh>",
#  'i️ just had a random delivery guy check my legs out. he said he could tell i run because i have the legs for it. <lh>',
#  "@realdonaldtrump it's been on the news all day. ur just fishing praise. again. <lh>",
#  'just saw the phrase "luxury fall-out shelter" in a new story. <lh>',
#  'i just saw a tumbleweed cross my path for the first time <lh>',
#  "@dominicanlil hahahaha i don't feel you nodoglyf wishihadadog lilmelo <lh>",
#  'first day with this kiddos! going to be a good year!! <lh>',
#  'having a routine really does help you get through your week. <lh>',
#  '@vikings you guys broke the redskins game sack streak. <lh>',
#  "@geico_service why am i on hold for over mins to request roadside assistance? mobile app wasn't working. hung up! <lh>",
#  'thanks to the awesome team at @ltdmove today for moving us from the shoebox to the new home and offices. <lh> service',
#  'holy shit confirmed fuck boy. he broke the bro code wowowowow <lh>',
#  '@realdonaldtrump other places have been hit by a cat hurricane its not a first you are failing yes puertorico is island in water <lh>',
#  '@realdonaldtrump did you hear about the fake fox seth rich story? <lh>',
#  '@realdonaldtrump some people take opioids to mask the pain of having you in the oval office <lh>',
#  'my boyfriend and girlfriend both gave me a s/o on insta today 😩 <lh>',
#  'nah seriously how the fk am i gonna pull together $ for falls when i struggle getting $ together for an event🤦🏼\u200d♀️ <lh>',
#  "@teresamaymp how is it your husbands company haven't paid corporation tax for the last five years? <lh>",
#  '@virgintrains truly shocking service in st class this morning, . retford-newcastle. finally offered coffee at .! <lh>',
#  'i think i have an obsession. looking up damon posters because i have to have one. 😍 vampirediaries yes obsessed <lh>',
#  'for better or worst i still will choose you first <lh>',
#  'guys, the amount of jinhwi today got me super dizzy. <lh>',
#  "well, i did it. i registered to write the @iabc gccc scmp exam in yyc in october. i can't wait! certification communications <lh>",
#  'dear ones, you are not alone, the unseen realm is active beside you. if you struggle, if you need a home, ask for help. <lh> 🌻🥀🌻',
#  'greatful for summer but also greatful for gel pens. <lh>',
#  '@thewizz @thehock @pdean @mudra showed ange our gf crew photo!! mentioned supers and goldenboys!! justsayin got <lh>',
#  'is the grass greener on the other side, or is better the devil you know the right way for now? <lh>',
#  "i feel like i'm finally coming into what my purpose is as a human being on this earth. i won't forget this day for a very long time <lh>",
#  "when ur craving sumn and then u get it and it doesn't hit the spot <lh>",
#  'i love it when every one is getting along. no fighting, no problem. <lh>',
#  '@heidiklum @timgunn @georginachapman which of all of you knew about weinstein sexually harassing the project runway models? <lh>',
#  'humans are still humans it dont matter what color ur skin is or where u come from loveislove <lh>',
#  'when your husband forgots to turn his alarm clock off and its a bank holiday. that. <lh>',
#  "@hewzylfc them silly fuck wits r clueless!!! the way klopp is set up!!! he's happy sure... <lh>",
#  'dqs pumpkin pie blizzard is awful! it tastes like squash baby food 🤢🤢 nothanks babyfood <lh> trashit',
#  'federal building 🥗🥗 wilshire blvd los angeles,california serving -pm!! westwood <lh>',
#  '@cnn she will say anything to defend her million dollar mortgage! <lh>',
#  'just watched babydrivermovie at the cinema, never seen music fused with life like inside my head before &lt; <lh>',
#  'so much talk about scaramucci , scaramucci, but no one has asked will he do the fahndango. <lh> <lh>',
#  "i'm playing against deshaun in fantasy. i hope he does well tonight but the rbs get all the tds. <lh>",
#  'accidentally deleted the video i was going to upload to my channel 😫😡😤 dumbass <lh>',
#  "starting high school in days i'm so not ready im going to get so lost 😂 pray for me guys😫🙏🏻 highschool <lh> <lh>",
#  'someone anyone hit my dm ’s... i’m bored bored dm <lh>',
#  'cryptonerds push-ups and squats every hours. then get back to blockchain <lh>',
#  'har£ee reitzel, you have been my saving grace thru the storm. ♡♡ <lh>',
#  '@srlcare cheap gimmicks by srl that phine was not reachable try something new. <lh>',
#  '@hind_modaimegh my cat says that to me every morning <lh>',
#  'waiting for my mac to update 😾 looonngggg <lh>',
#  "@timesofindia @mamataofficial look who's talking abt culture n heritage !! <lh>",
#  'praying more for @vancepitman, pastors and believers in las vegas area during aftermath of this nations largest mass shooting. <lh>',
#  "it's october and now i can watch ghost adventures on repeat. <lh>",
#  'the things my friends do for me just leave me like wow! feelingspecial <lh>',
#  'just got invited to a kids birthday party by the person who manages our paper goods. she told me to bring my children. im <lh>',
#  "you built a fire for the both of us to feel but now, it's being put out by my tears. <lh>",
#  "ok, but seriously, we're not getting just card reveal today, right? 😰 frozenthrone <lh>",
#  '"for by grace you are saved through faith; and that not of yourselves: it is the gift of god." -ephesians : <lh> <lh> <lh>',
#  'planning a disney vacay with my baby 💞😍 <lh>',
#  '@gizmostripeycat @cand_mk @socalbarb @ckkoch @charlesmblow oh my...you don\'t understand what a "play on words" is either. <lh>',
#  "i have a closet w clothes,shoes, purses, kids who❤️me, excellent health etc-money won't change my life-prayin honest love💘🙏😊 amor <lh>",
#  '@realdonaldtrump please just stfu! you are the biggest fucking moron of all times! <lh> <lh>',
#  'as if some random bloke wi his family just paid for my order at maccies drive thru <lh> 🙌🙌',
#  '@realdonaldtrump once more applauding bigotry and racism. a clear pattern of where you stand. notamerican <lh> notmypresident',
#  "@cumbubblejesus oddly enough i couldn't remember my login for them this morning then it came to me when i saw this. <lh>",
#  'years ago today, i became friends with people that gave me the most incredible experiences and memories, forever grateful! <lh>',
#  'is rick perry implying that people don’t get beat with the lights on? <lh> resist',
#  'perfect end to a fab weekend. reading a book in a bubble bath. <lh> <lh>',
#  'and even if i was afraid, even if i was running away from her love is a non-degradable atom. <lh> bepatient dontbeafraid',
#  'woke up to the best text in the world💖 <lh>',
#  'no matter what happens in life , i know i can always count on my wonderful family, my loving husband & my caring friends 💕 <lh>',
#  '@skysportswwe @summerslam hope i win never been able to abroad and always dreamed of going to a big wrestling event <lh>',
#  'how would gordon ramsay rate and react to the jaulo i just had 😯 <lh>',
#  "cozy is a vibe go listen to it, i'm really proud of you jacob @jacobsartorius <lh> ❤",
#  "fieurope is about to open and we can't wait. come say hi at stand .r <lh>",
#  'sita : who are you? desperate ravan : i am despasito <lh> pj',
#  "in other news, football is almost back. and i'm alive. <lh>",
#  'so i have to assist you on how to exit the building? do you need me to wipe your ass too?!? 💁🏻 customerexperience <lh>',
#  'yayyyy!!!! congrats to my ladodgers codybellinger rookie of the year!!!!!!!!!!!!!!!!!!!!!!!! thisteamla <lh>',
#  '@jessesingal dang it. before the pic loaded i was hoping for baby geese. instead got booze & some dude <lh> 😆',
#  'unstable and not competent to lead were the obvious flaws of the man during the primaries! <lh>',
#  'saturday night with christian and lucy in wiltshire was such a vibe!! thanks for having us, have a lovely honeymoon <lh> feverforever',
#  '@paonthemic it’s working out house of pain in full effect! gotta hit those two though! <lh>',
#  '@maddow well the far-right patriot that assassinates bergdahl use the commander and chief instructions as a defense? <lh> believeme',
#  'diseases are molecules misbehaving; the basic requirement of life is metabolism, and death its cessation - dr. paul kalanithi <lh>',
#  "@kingjames i didn't know a line of is that aggressive to shut down an app.... @blazepizza <lh>",
#  'when the team ask if you prefer women or men! it makes it so much easier coming out as gay police accepting gay <lh> team <lh>',
#  '@komalsp the cbo consists of about budget experts who create new models everyday. but trump says he knows <lh> hehasahunch',
#  'so a year old scumbag luke woods gets yrs mths for punching & killing a pensioner. will be on his release! madness nojustice <lh>',
#  "@esotericpagan he'd make a better job of it 😂😂😂 @dogcelebration dogsoftwitter gardening lawnmowing <lh>",
#  '"do i look like i retained any of my degree? look at my face." - @s_aktar did a maths degree but can\'t help her sister with stats <lh>',
#  "@rickcasemazda days since i purchased my mazda at pleasant hill in duluth ga. still haven't transferred my title! <lh>",
#  'anyone else waiting with bated breath for the st tweet from @sandringhamsch peaks ?? 😃 suspense nonewsisgoodnews <lh>',
#  '.. "the blessings of god dey follow, e dey for body like logo and stand gidigba like iroko..." ogaranya kcee davido <lh>',
#  '“new day, new hopes, new life!!” <lh>',
#  "@newsandguts that's right, line up for those minimum wage jobs! <lh>",
#  'when we miss the kindness of god because we have not prayed, it is hard for us to be kind to others. <lh>',
#  'dustin just put $ in my account <lh>',
#  "hun, read it again. that western stan's tweet applies in every k-pop group. you both really match together. <lh>",
#  'we all have our own gifts, just be happy <lh>',
#  '@phoenixnewtimes 👇🏻👇🏻👇🏻👇🏻this is who @realdonaldtrump considers a good person. <lh>',
#  "@realdonaldtrump your new full of lies attack ad still doesn't change the fact that you employ racists and are a racist pos yourself! <lh>",
#  '@cnn these young people came here with no agenda except to be with their parents mr king. you should resign and live in the shadows. <lh>',
#  "i swear my mentor always knows what to say. ✨ there's power in words, advice, and good perspectives. <lh>",
#  'i just... i just dont even know anymore. <lh>',
#  'baelish was the most captivating, mysterious character on gameofthrones and the writers just destroyed seasons of his story. <lh>',
#  'leaving the ashes for vasc to watch newcastle be all pretty & shit. and she is turning it on! hometown <lh>',
#  'playing @thebassmentclub in chelmsford tonight with trio and vicky martin check us out .pm wells street,cm hz gig blues <lh>',
#  'universities are expensive enough and now every time we make a payment we have to pay extra?! 🖕🏻🙄🖕🏻🙄 <lh>',
#  'would it be wrong to get a dirty burger and milkshake around now....? <lh> dreadingthehangover',
#  'cnn or fnn has less viewers than decade old reruns of yogi the bear...😂 <lh>',
#  'youtube...i am not a hater...bacon strips for all <lh>',
#  '@hkane u had job to do at today put the ball in the back of the net fucked my triple points captain right up in fantasy football <lh>',
#  'first day back from hols, first call received! @craicni has been invited to pitch in dublin next month! craicing goodcraic <lh>',
#  '@donaldjtrumpjr he claims to be worth $ billion and it took him this long (only after being shamed in the media). <lh>',
#  "never ignore a person who loves and cares for you, cause one day you may realize that you've lost the moon while counting the stars. <lh> …",
#  '@proverbmusic i was one of those students <lh>',
#  'this going to bed at am and being up from pm-am has gotta stop sleepproblems <lh>',
#  '@shotinthedark i mixed versions of "bring me to life" by @jenhopemusic and @evanescence <lh> powerful',
#  'ooo ooo i can do it too says the dumb one haha <lh>',
#  '“i’m beyoncé and you’re just a forgotten member of destiny’s child” @melisadiane everyone. <lh>',
#  "she's being a pretend ho, bless her heart. <lh>",
#  'we had a spectacular time at ydadal this weekend and are reenergized for this school year! more info on our first meeting to come! <lh>',
#  'can’t stand how everyone is up jax butt cause they shut out a broken down indy...notimpressed <lh> 😑',
#  'reading quiz a success! proud of my babies...they work so hard and are so bright and intelligent. <lh>',
#  'i had a dream that @benshapiro stopped by my office for christmas and left us all very practical christmas presents. <lh> imnotcrazy',
#  'my prayers go to texas in this incredible time of need. have your hand over those people, god. <lh> godwatchoverthem',
#  'just noticed the devil himself is friends on facebook with sara <lh>',
#  "@nikifirmin you're very welcome niki! you're so incredibly talented! your work is absolutely amazing! x niki <lh> <lh>",
#  'can’t wait to move into my new apartment tomorrow 🙌🏼🙌🏼 <lh>',
#  "@dominos_uk never had to wait an hour and a half for an order to arrive! 😤 and it's still not here! <lh> <lh>",
#  '@nidhi her statement proves why we call muslims bigots and we hate them ! can never utter a positive word for nation. <lh>',
#  'steps, laundry done, groceries and movie. great day!!! dayoff <lh>',
#  'life n days ... 🏃 through the hustle we survived jah thanks for seeing another blessed day 🙌🙏 am <lh>',
#  'how are they gonna have hercules on netflix but not peter pan? <lh>',
#  'family day: reunion of the entire shawn ray family❤️ <lh>',
#  'spent all day trying to figure out a stats problem for my thesis only to discover it was a red herring <lh> makedatagreatagain',
#  "mike you knew you didn't like her that much. you only wanted the pussy and that's wrong. she didn't know that. sickinthehead <lh> wtf",
#  "@shsanders when you give your daily press briefings do you honestly believe the bs you spew? if you had a brain you wouldn't. <lh>",
#  "remembering @admiralmcraven's speech & although science is going terrible today, i did make my bed and hit the gym, so i feel <lh>",
#  'holy crap! i’m literally caught up on editing senior sessions & almost done with the wedding from last weekend 😱 <lh>',
#  'insecure is the black sex in the city <lh>',
#  'katie and i️ made pies in hrs mins. <lh>',
#  '.@realdonaldtrump to puerto rico: every death is a horror but if you look at a real catastrophe like katrina.... <lh> areyouserious 😒😒😒',
#  'every time i get donut holes from dunkin donuts they always give extra 😍😍 <lh>',
#  'homemade spag bol nd garlic bread, bath, pjs, fire and candles on with my boys <lh>',
#  'piracy hacking the entire world loses. congrats to fang making it happen! @mcuban @potus @ronwyden @russia @pontifex @benioff purpose <lh>',
#  'one more week until my daughter turns two <lh>',
#  'why did gypsy get cancelled? i like it so much. <lh>',
#  "obviously they mean something else or they still don't see it. <lh>",
#  'been loving how worthless @ask_spectrum internet has been the last month 🙏🏻🙌🏻 <lh>',
#  'hit my head so hard yesterday i gave my self a concussion <lh>',
#  'i have serious trust issues... so many people have destroyed my <lh>',
#  '@realdonaldtrump @whitehouse you and ivanka ever going to make your crap here? hypocrite <lh> liar',
#  '@aintarmed @roaa_sabry 😍😍😍😍 can give my life up fore someone like this..😍😍 <lh>',
#  'dear @mcdonaldsuk. thanks ever so much for considering my waistline by only giving me nuggets in my box of but i paid for ! <lh>',
#  'so @dangerusswilson did the lord tell you to disrespect the flag? not sure you’re listening to him these days. <lh>',
#  'love @mileycyrus new song called "week without you". such a great tune by my favourite singer x mileycyrus youngernow charts <lh>',
#  'shout out to the little cesar’s guy who gave us an extra pizza for laughing at his joke <lh>',
#  'thanksgiving, to be truly thanksgiving, is first thanks, then giving. chsrise <lh>',
#  '@chizzyakudolu this is one of the reasons why i prefer animals! animals do not discriminate! <lh> ignorant',
#  'thank you, @npolyak & @mikelubelfeld and your incredible book @unlearninglead! it has inspired our pd vision for this school year! <lh>',
#  '@boyscouts you owe your scouts an apology for inviting trump to speak at your jamboree and demonstrate the opposite of the bsa oath. <lh>',
#  '@cbssports @k_kisner show some class with the snuff hawkers. your on tv spitting every minutes. <lh>',
#  'my love @summerleanne made me an amazing breakfast this morning to make sure i ate before my interview. <lh>',
#  'finding out that british airways are extending there strikes for atleast weeks and i leave in weeks days😬 <lh>',
#  "@armoyroadraces @keithamor what is keith doing with himself now that he's retired? <lh>",
#  "i hoped that institutions such as collage and university would manage @wikipedia it's not trustworthy and unethical in loose canon <lh>",
#  'im not trying or doing shit for you anymore 💯 <lh>',
#  "death is a respecter of no one irrespective of who you are, what you have or who you know. only by god's grace... give thanks. <lh>",
#  '@absentiaseries has there been more news about the us network that picked up absentia ?! ivebeenunderarock didimisssomething ?! <lh>',
#  "something trying to stop me but i always get it done % downloaded crazy it's taking so long strange.but it's ok real ufo <lh> <lh>",
#  "@snookums_ feel bad cam'ron came outta hiding only to go missing again <lh>",
#  "rebound sex with your ex is trash trash trash. don't dooooo it. all puns intended. <lh>",
#  'thisislife wow what an amazing episode. @lisaling you had me in tears during the last segment; you liked what you saw! beautiful! <lh>',
#  'filming is spectacular in blacksunday. use of nfl & goodyear gives realism to the story. edge of seat watching! football <lh> tv',
#  'more days until. t blackfriday box from @efxsports arrives <lh>',
#  "@scaramucci colorful language?? are you kidding me? you're insane. children are listening and looking for leadership. <lh>",
#  'can someone tell me why home boy would vent to his old girl about his new girl .... cause i dont get it <lh>',
#  'congratulations to @elitomac on a great season and winning the motocross championship <lh>',
#  "@lindseygrahamsc you are a tool- stop even pretending you're appalled by this administration allwordsnoaction <lh>",
#  "@tbonewfnz don't forget the colts/browns coming up this month <lh>",
#  '@pontifex praying for you @pontifex as i expect you are praying for me as our father guides me with his will. <lh>',
#  'i went on this @tindr date a few nights ago and i might as well have eaten a wet slug because i left <lh> & disgusted.',
#  "@jerryghazal and here's another yes from me <lh>",
#  "@pictureplane because trump's maga is taking us back to when he grew up in the 's. <lh>",
#  'it took years to get my vocal cords strong enough to yell. <lh>',
#  'i booked my tickets minutes ago to see @carriehfletcher @oliverormson @sam_womack & the incredible @addamsfamilyuk cast tonight! <lh>',
#  "just got proofs of brightsword byrhtnoth from @bookguild where's my red pen? <lh>",
#  'the moment that your family finally accepts your man and you can take him to sunday dinners. after years ❤️🌈 <lh> <lh> <lh>',
#  "i've suddenly come back to life. thanks to the amazing ls doctors for reviving me. <lh> <lh>",
#  "i'm surprised at how everyone seemed to have a lit sunday night lol <lh>",
#  "never loan me money cause you won't get it back why you ask because i'm broke af 🙂 <lh>",
#  '@realdonaldtrump drops the news he pardoned a racist murderer in hopes that the cat. hurricane hitting texas will cover the pardon <lh>',
#  'she one asked me money for an ipod i dropped by accident that she found and i needed to pay her a new one .. <lh>',
#  'i’m actually studying... what’s gotten into me? <lh>',
#  'ladies stop attending awards and shows , pantless with transparent gowns to show "it" out. <lh>',
#  "with @ripleychandler and got catcalled... 'got a boyfriend?!' not aure which of us he was yelling at... <lh>",
#  'i said when you cut from a different clothes,it simply means you chosen(special).foc <lh>',
#  "lady gaga got engaged and it isn't to me???? <lh>",
#  "@rachelmsilva_ idk we'll find it, put it on the to-do list <lh>",
#  'what kinda guy sends dick pics to his best friends ex girlfriend. winnerrightthere <lh>',
#  '"tasteful love scenes" is redundant. all love scenes are inherently tasteful, because of love. center your tastes around love. <lh>',
#  '@callofduty retweet my friend got resest from to he lost his prestige token he got for pre-order everything he had is lost so <lh>',
#  'never grow a wishbone daughter, where your backbone ought to be - clementine paddleford <lh> <lh>',
#  '@elementbrand what the fuck, you cant even type your details in quick enough! shitservice <lh> 😒',
#  'need a tuna sub backwards lol 😂 <lh>',
#  'home time... pamper night and early night for me👌 <lh>',
#  "no don't give lawrence the couch! she should keep that memory for her <lh> <lh>",
#  '@beschlossdc @joenbc and today trump is dog-whistle tweeting about ungrateful lavar ball instead of recalling this tragedy <lh> norespect',
#  'ordered a set of microphones for better audio and coverage. hope this helps for next session. plans <lh> <lh>',
#  'up till : only to wake up at and be on the shuttle for work by <lh>',
#  "usa fought nazism in europe & now @realdonaldtrump encourages it here. that's maga for you. <lh> charlottesville",
#  'game ! dreamstones is just days away from being released. excited and anxious! indiedev gamedev <lh>',
#  'really @nintendoamerica? no local multiplayer for splatoon ?!?!? what a joke. first the ludacris chat by phone then this. <lh>',
#  "@thekenyeung @spectacles @xoxolizza @willjamieson i'm all about that <lh>",
#  'i just wanna be free from trap of the devil come now and save me, look at me now i need your help <lh> _',
#  'going to see thelastjedi in days with my babe @pattiiii <lh>',
#  'paul, taking my fries: “if you’re too weak to defend them, you don’t deserve them” 😂 <lh> survivalofthefittest',
#  'great times at the wibca montreal christmas party tonight. community <lh>',
#  '@cusackmaddy @taylorswift yo i️ actually thought the same thing???! <lh>',
#  '@laurendawnfox know the sun shining all around you <lh>',
#  "-how the fuck i got more followers that aren't on my friends list stalking me then actual friends curious about what i'm up to.. <lh>",
#  'make a young brazilian student happy with his donation of bitcoin or litecoin my portfolio ghwzdqscvabuekzdfnaawweoorvcbitcoin <lh>',
#  'when hope is low, faith has the ability to build you back up...and vice versa. <lh>',
#  "it's a good day in your actorslife when you get cmail thanks to @actorsaccess <lh>",
#  '@mathewjarcher @thetattooedpt ck model seems to have changed her mind! <lh>',
#  'i honestly don’t think i’ve ever felt this much joy- pure joy in my life. excited is definitely an understatement!!!! <lh>',
#  'shout out to the @chiefs for supporting someone who beat the shit out of his pregnant girlfriend. <lh>',
#  '@lorafulton yeah. alot of good people..alot of great donations. <lh>',
#  'i love how the same course can go in different directions from one group of students to the next. watching learning in action is <lh>',
#  '@mosmyth very well aware! massive @ukfallstars supporter. <lh>',
#  '@realdonaldtrump i heard something sir, i heard that you are a looser and spread fake news to foolish people. <lh>',
#  '"for he shall give his angels charge over thee, to keep thee in all thy ways." ~psalms : <lh>',
#  'all i wanted was someone to cross my bucket list off with. all i got was let down. done bucketlist <lh> nomoredating',
#  "i've seen dogs and cats since i've been back home. <lh>",
#  "sorry @neneleakes rape is never ok to joke about. ever. as a woman you should know that. what's wrong with you? <lh> neneleakes",
#  'escaped the grey skies of england for the pleasantly warm sea breeze in gibraltar. holiday <lh> fridayfeeling',
#  'no... not just better but perfect. we are ok in here as usually. its uptoyou <lh>',
#  "@dallaswings that's what i am talking about my dallas wings get the win 🏀 <lh> it",
#  "the love of christ is so powerful, that when it goes through every vein, you can't contain it and the joy is overwhelming! <lh> hislove",
#  '@mcdonalds love ordering food, getting home and realizing they screwed up my entire order and i didn’t get half of what i paid for! <lh>',
#  'molly lovessss the forbidden fruit smh 🤦🏾\u200d♀️ <lh>',
#  'turns out they ended up being allies to adversaries in commerce. awee! 😭😅😂 <lh>',
#  "i still remember other people's ids and mine from university: ndf, jmh, jpa, bcl. @penn_state <lh>",
#  '@jonostrower sad that my baby is no longer that popular - <lh>',
#  "i drove by subway earlier and started laughing hysterically because i think it's funny they're still in business <lh>",
#  "@thealbumsurgeon it was cool then, now it's just <lh>",
#  "i love deadline day. can't wait for norwich to go buy some world class players <lh> ncfc",
#  'idk, idnt understand,how the guy tht reminds u of yurself..🙃is the u r sending home thebachelorette <lh> 🙃♥️🙃♥️🙃♥️👎',
#  'oh boy. you guys, our new business cards and print materials are out for delivery. <lh>',
#  'i was on some drunk shit, put it down somewhere & don’t know what i did with it . <lh>',
#  'thankyoudonnie you are the the reason i connected with so many people forever <lh> 💜💜',
#  'i know its early days but i would like to thank all my fans for their support, <lh> <lh>',
#  '@ivankatrump : ya know. these are ur dads ppl! plain & simple! <lh>',
#  '@yondermountain pumped for your show tonight in rochester. first chance we’ve had to see you fine folks in a few years. <lh>',
#  "@jossandmain i direct-messaged you the details of the defective furniture you sold me, as asked, but haven't heard back. getting <lh>",
#  '@seanhannity your audience? is that the same audience that has been losing the ratings game to msnbc, <lh>',
#  "in the end, these remain: faith, hope, and love; but the greatest of these is love. (it's in the bible & true for everyone) <lh>",
#  "retweets and likes on my muscle ups on deck video, that's awesome! thank you everyone 🙏🏽 <lh> <lh>",
#  'had a dream about an ed sheeran video game... maybe i should study computer science to make my dreams come true 😂. @edsheeran <lh>',
#  "watched @fawadchaudhry comments about ayesha gulalai's sister. he-particularly pti-is setting new records of indecency. <lh>",
#  'so proud & happy as this healthy eating is paying off. i can now fit in my favourite white jeans after a year of not being able to <lh>',
#  '@nra christian white guys are now the domestic terrorists in america. be proud assholes. this is your base🖕🖕 <lh>',
#  '@tomarnold even in the miami heat, donny still had shrinkage. <lh>',
#  'everyday brings a new beginning and a new hope. have faith and find good and positiveness in life. mondaymotivation life <lh> happines',
#  "going school for the last time to pick up my son . feels like i'm off on holiday ... schoolsoutforsummer <lh>",
#  "i had a dream that @vancityreynolds punched me in the face, now i am legit mad at him... i don't know how i feel about that <lh>",
#  'been waiting for someone to come and sit me at the @allstarwings in pickering for mins. no one has come!!! horrible service <lh>',
#  'i remember @miyatola shooting "nothing less" in sneaker shop in long beach w/ a less than stellar camera...my nigga got a vma tonite! <lh>',
#  '@likesummerfilm nnnooooo. okay i will try to find something better. i ha e to see this movie. the books changed my life haha. <lh>',
#  '@olimauritania @twitter and your black ass is defending an adult male why? <lh>',
#  'if she saw me the earth would trimble & she would just stare. her eyes are bittersweet w/ love that we both refuse to share. selfish <lh>',
#  "it's such a blessing when my eyes get to see the sunrise. <lh>",
#  "@therunchat going down! with summer temps, it's better for the skin too! but aren't mornings just so beautiful though? <lh>",
#  '@janabananababy this one guy changed the free bag when we already paid the badminton racquets on our way out. <lh> 😒',
#  'i need more oomfs but they never follow back <lh>',
#  '@coxcomm @koconews you guys are losing customers and viewers! figure out your drama asap!! <lh> <lh>',
#  'this season of the flash feels very season one. <lh>',
#  'omg! wow. i’m getting younger! just a minute ago, the clock went from am to am! young youth <lh> notdrunk',
#  'just figured out my phone charger is the perfect length so that i can charge my phone while i poop <lh>',
#  '@juumonje the belle of the ball this past week. congrats again on an a-mazing show, and was so happy to meet your family! <lh>',
#  "i can respect you but i don't love you.we are just strangers trapped in the same place & time. i feel sorry for myself & i pity you <lh>",
#  '@catchfence @knighter the drought ended on a muddy track <lh>',
#  '... years young in days 🙌🏽 leoszn <lh>',
#  'stranger outside of the vet: "see my thumbs? they\'re both up in the air you. thumbs up. and for your little dog too." shesacat <lh>',
#  '@thehill really whitehouse how far in the gutter are you going to let this trashbag @realdonaldtrump take you smh <lh>',
#  "i'm on the train laughing out loud like a crazy person peterrouse belindablinks @dadwroteaporno podcasts wittybrits <lh>",
#  "todd gurley just exsplodes when he touches the ball like he's just immedatly in full speed <lh>",
#  "i can't take anymore. i really can't. <lh>",
#  'being able to pay all our bills, pay off one of our debts, and have some money to spare <lh> isturningup',
#  "@realdonaldtrump ashingtonpost @cnn no one likes you. you're a total loser that is clueless at his job. <lh> losing impeachtrump",
#  '@urbanachievr @yummycovfefe @yogagenie @mitchellvii does “them” mean black people? <lh>',
#  'psg just doing to celtic, what celtic do to the rest of the spfl. bigger budget, better players, better manager <lh>',
#  '@giantaks truestory ...and this is why i love you. givenofucks <lh>',
#  'my boyfriend really spoils me all the time. <lh>',
#  '@realdonaldtrump still calling names like a rd grader, i see. sure wish i could respect the potus whether or not i agreed with him. <lh>',
#  'opened my window last night and i woke up shaking because it’s too cold. 🙌🏻 <lh>',
#  'why does it take many good things to build something and just one thing to fuck it all up?! 😂😂 <lh>',
#  'our great god abundantly offers himself to us, may we come to know & love him more and more. <lh> godisgood <lh>',
#  'when your homie comes through for you.. you tha one🙌🏽 <lh>',
#  'as soon as you think life has gotten as bad as it will get something else happens <lh>',
#  '@rararyan having a client with the courage to execute on a rebrand this extensive played a huge role in how well this turned out. <lh>',
#  "@free_dowlin_ @greg_pomes he doesn't walk anywhere. he drives a half a block to the gravy store. <lh>",
#  "i'm not sure why i have to turn on the tv just to look at my phone, 🤷🏻\u200d♀️🤦🏻\u200d♀️ pull the plug, i might as well be dead inside. <lh> iphone",
#  '@atensnut how dare @hillaryclinton! her husband was a predator and deviant, and she covered for him and enabled him. <lh>',
#  'i swear my roommate must like rub shit all over his room because it smells terrible and it’s like leaking into the hallway. puke <lh>',
#  'so there we go, @eos_io public key registered to my @ethereumproject address that holds the tokens ... all set. somemonthstodo ico <lh>',
#  'for our month my significantother made me get back onstage for the first time in months utterly inebriated. <lh> killedit <lh>',
#  '@pickhurstpta lovely to see lots of familiar faces from our pickhurst class through the years in the cast & audience of aladdin <lh> /',
#  "i sample cakes tomorrow and i'm pumped 😋 -- will be here before ya know it! newdate gettinhitched <lh>",
#  "@gmb don't get me wrong i love a night out (& really need one at the moment) but it's about knowing your limits excess <lh>",
#  'you know what kindergarteners are too old for? pacifiers. really? <lh>',
#  "cheating on lawrence with daniel, couldn't be me. <lh>",
#  'fun xmas event at central street infants today hebron bridge @caulderdale funfit <lh>',
#  'i noticed changed but it was quite subtle. <lh>',
#  'got so many ideas for this halloween!! hope things go as planned 😍 <lh>',
#  '@trumpusa impressive. fake clinton story, real dossier you called fake & a fake meme about a war hero. conspiracy theories much? <lh>',
#  'idea for the allstargame next year: a single derby. they’re apparently tougher to hit than home runs at this point. <lh> worldseries',
#  'i committed facebook suicide last night and no one has noticed <lh>',
#  "and never stick to those who morph themselves in to what you envision them being. just be yourself and you'll attract what you want! <lh>",
#  'yo, uva is so fun to play. 🤣 we can literally play awful and still win without a doubt or ounce of stress. <lh> straight',
#  "missed celebrating my th anniversary @golfsupers last week! i've been privileged to work for some awesome members <lh>",
#  'i would love to merge my @hbonow sub into @hulu... but why is hbo % more through hulu? <lh>',
#  '⭐️ when you know yourself, you are empowered. when you accept yourself, you are invincible ⭐️ motivation itcomeswithage <lh>',
#  "i tell ya... i was really born with the odds against me. but somehow, i've always had the spirit guide me... good karma coming <lh>",
#  'skinnyrepeal republicans and @potus hurting america is the goal of the republican party <lh>',
#  'my only goals involve my son and bettering my life for him. <lh>',
#  'tonight was such a juxtaposition to pride last week <lh>',
#  '@netflix thanks for taking away almost all the seasons of familyguy & americandad and pretty much all of the good fox tv shows. <lh>',
#  '@scentbird love the idea. recently became a member and received the two of the same scent with a week of each other. <lh>',
#  'headed to phoenix, ar for impartation at the idnsummit but it will be nothing like the impartation at theencounter @iamswata <lh>',
#  'one of the worst tragedies in this life is taking a onetimeopportunity for granted and not being able to get it back when it goes. <lh>',
#  'thank you @surreycouncil & surreyhighways east lane kt had been dangerous. road surfacing is £££ but now safer and quieter. <lh>',
#  '"but those mine enemies, which would not that i should reign over them, bring hither, and slay them before me." ~luke : <lh>',
#  'that random moment when your just laying on the couch and your dog walks up and just pisses on your shoes <lh>',
#  '@poferries trying to book a minicruise from hull to amsterdam, but keep getting a server error page when trying to pay <lh>',
#  'got told i was "old" at the bar last night <lh>',
#  'just got another design job & design work finished for the day. <lh>',
#  'you will never catch me behind the wheel of a self-driving car <lh>',
#  '"u wanna block me like u mutombo my nigga?" 😂😂 <lh>',
#  'im a blessing,a husband,a dad,im climbing the impossible mount everest,im going higher up the climax,watch & learn as god takes me up" <lh>',
#  'mama, do you want to be my buddy forever? yup. <lh>',
#  'for most people they sleep to dream, explore things they never could. but i am a writer, and we writers explore dreams through words <lh>',
#  "after all this happen i guess whatever i want to do it's on hold untill next year.. try to have positives mind now.. <lh> onhold",
#  "@theeconomist without significant cost reductions or single-payer, isn't that kinda like forced bankruptcy for the poor? <lh>",
#  'eminem is trying way too hard to maintain some semblance of relevancy. <lh>',
#  'unbelievable how james woods went from riches to rags because of his extremist ideology on twitter. he blames it all on jewish people. <lh>',
#  "@rogers absolutely sick of rogers!!! cable tv is garbage!!! next box is garbage!!! everything is new and it's nothing but garbage!! <lh>",
#  'today is the day that this program has made me reevaluate and question my whole life. <lh>',
#  '@idea_cares you are hopeless & a bunch of liars !! sorry no customer care at idea !! <lh>',
#  "two duvets on tonight. i am truly living the dream!! c'mon!! <lh>",
#  '@kansascityfish @cheecheebecker it would be a good investment. if only it would work. <lh>',
#  'dear matiangi , do let our christian, hindu and our brothers and sisters from all other religions; celebrate eid with us. <lh> <lh>',
#  '@susannah_kim @afterbuzztv @monsebolanos bad to hear well for me haha but i hope u enjoy your out of townish .. me too <lh> and waige..',
#  "@blackveilbrides when you've been saving money for over a year to see one of your favorite bands on tour <lh> <lh>",
#  'all her character does is scream. it got annoying real quickly. ahscult i hate clowns, but this is <lh>',
#  'couldn’t have spent tonight any better than i did <lh>',
#  '@stellerjay @nysafeact @hillranchers @bobsamuelson @larrypratt was that even english? as an attorney, i would have expected better. <lh>',
#  'everyone: @edsheeran’s thinking out loud is the most romantic song of all time and cannot be topped @edsheeran: “hold my beer” <lh>',
#  'saw @chancetherapper on the first leg of his tour in sd now i get to see his last show online? <lh> hurricanemariarelieflivestream',
#  '@bbcworld his whole "presidency" has been a golfing vacation. @realdonaldtrump <lh>',
#  "@pitapitusa just violated my taste buds. i'm going back tomorrow. <lh>",
#  'today: presentations on slaaash, asl signbank, and asl-lex @ gallaudet u in dc. come to ling department -pm asl <lh>',
#  '@keithdyer searingly hot takes on the *new* shape of the rectangle valueadd <lh>',
#  "@nbcpolitics where are we supposed to call or text to vote for who is trump's ? <lh>",
#  'noah’s three sons were so lucky... their mother in laws weren’t allowed in the ark <lh> 😂🙌🏻',
#  's/o to my mom for picking out a nice groutfit for me to wear to my surgery <lh>',
#  'signed up for online schooling to upgrade, time to get my life on track 👊🏼😌 feelingdetermind <lh>',
#  'i think i can count on one hand the amount of times i had fun on new years eve. <lh>',
#  "seth lugo's final line: . ip, h, er, bb and ks! <lh> <lh>",
#  "feelin' air headed day; about deal w a split personality client-we'll see how it goes cuz i feel pretty split too😂❤️ <lh> mentalhealth",
#  '@loochmunz ahh, so you were using cuda and seperate blender instance for cpu rendering? <lh>',
#  'had an amazing week of rehearsals for singing in the rain! what a dreamy show and such a lovely cast! ❤️⭐️🙌🏼☔️nextstopparis <lh>',
#  '@amychu @dynamitecomics got dangit. i was late for a lunch meeting and never got back to the artist alley! <lh>',
#  "how many times in my life will i need to tell someone there's a fish in my cup? in portuguese? asking for a friend. <lh>",
#  "@foxnews he's actually committing child abuse. contributing to the delinquency of minors is child abuse. and what's he sitting for? <lh>",
#  "president trump sure has a lot of energy. i think he's been using the white house treadmill on that chin and neck. <lh> youngstown",
#  '@andy wow! the tension in the clubhouse 😮 glad i am not in there with. looks like you need to escape wwhl <lh>',
#  'girl,if i cared abt what i looked like i would show it,obviously at this point, i do not care😂😂😂😂 <lh>',
#  'it’s so obvious that puerto rico is not a priority for this government. <lh> puertorico',
#  'smile and tell yourself, "it will be fine", while fully trusting in allah, that it surely would be fine. <lh> <lh> tawakkul',
#  "i'm such a g, my boss got me doing some advanced ass accounting i've never done before and i'm just killin it!🙌🏼 <lh> boss educated",
#  '"the god of all grace . . . will himself restore, confirm, strengthen, and establish you." pe : <lh> <lh> restore',
#  'joy does not come from things bought. it is different from pleasure. it has to be given and also received as a gift @ryonprice <lh>',
#  'this coo\' guys advice to me is "collect & select" & "be discreet" <lh>',
#  'had a great night with my girl tonight! <lh>',
#  '*probabaly* never gonna get used to walking into my humans workplace to girls with their trousers at their ankles 😂 <lh>',
#  'eating cheesy doritos whilst watching @sips_ play prison architect. god i love life. <lh>',
#  'i got blessed with the most beautiful baby girl in the world & amazing girlfriend who is the best mother to our child ❤️ <lh> thankugod',
#  'so umm you gonna tell ole girl you fucked her husband and he still pressed <lh>',
#  'my mom said me, maddie, & conner are invited to the company party <lh> <lh>',
#  'i cant remember who tweeted about eggs being chicken period..havent touched one since 😷😷 <lh>',
#  '@emilymmountford you personally sign each one of them? <lh>',
#  '"then said jesus unto him, except ye see signs and wonders, ye will not believe." ~john : <lh>',
#  "going thru my pictures just make me miss people i don't even talk to and it sucks 😞 <lh>",
#  'powerful is the devil. so watch out! <lh>',
#  'st_ti: sl / overs . munaweera out gunathilaka * imad / pakvsl <lh>',
#  "when sansa was pulling out the faces and for a second i got excited cuz i thought i saw trump's face, but nah @gameofthrones <lh>",
#  "so i think i like the duffer brothers as much as i loathed ra'uf glasgow. strangerthings <lh>",
#  "@deepstateagent @sweetteatimetoo @jsavite @realdonaldtrump don't forget the trump bots, tons of those on twitter too <lh>",
#  'when your day absolutely sucks, but that one person that makes your day perfect and everything so.. so.. far away. <lh> hero her',
#  '@theagent @cravenga gun .. the best in the business.. <lh>',
#  "i'm currently deaf in one ear y'all. i'm friggin sick and i'm not having it <lh> themucusisflowing",
#  '@xo_bekah @macmillancancer thanks rebekah money for macmillan and a great new look <lh>',
#  "got a jumbo phil's for the price of a large and it was here in minutes goodday <lh>",
#  "@lupinswclf same!!! wtf 😂 i probably met half of twitter there but i didn't know! <lh>",
#  'ok my bro offered me spicy tapioca and dark chocolate biscuits <lh>',
#  "there's a lot of sentimental value here. i've had this phone for , years & never changed that case. i deadass would feel less <lh> selling",
#  'you have to stop allowing that trial/tribulation to trump you instead let it have its complete work in you! character <lh> presson',
#  'asif you would pretend a make up look was your own work and advertise it for younique when it was your mua pal who did it <lh>',
#  'love_yourself brother you have been cleaned by the most powerful blood of <lh>',
#  '@samantharone looking forward to seeing you today at @exxxotica nj 😀 <lh>',
#  'everything i touch these days just goes right... <lh>',
#  "@drbatrashealth sharing number with you is of no use! we have to bear your craze for promotion! it's pity! <lh>",
#  'great & mighty god, awesome country, phenomenal family & friends. happy thanksgiving! <lh>',
#  'still trying to process the fact that anthony milner visited jalan merdeka and plans to go again because he loved it that much. <lh> 😭💕',
#  '@redskins @jungleboi_swagg if only he played like it. <lh>',
#  "i can't believe they literally made a whole movie of tony struggling with the reactor only to have him take it out in the next movie <lh>",
#  "@thomascookuk think yous need a new rep in magaluf. not turned up all weekend and has now left a sign saying she's back on wed? <lh>",
#  'getting my popcorn 🍿 and coke sitting on the couch getting ready to yell at the tv screen as i route for llws thundering lufkin <lh>',
#  'that big guy bowman reminds me a bit of elbows hateley <lh>',
#  'psalm : "the righteous person may have many troubles, but the lord delivers him from them all." <lh> <lh> <lh>',
#  '@ivankatrump maybe you should let your racist daddy know... complicit <lh>',
#  '@miss_missa i would like you to know i dreamt that i tried to make our painting again and was more successful in copying bob ross <lh>',
#  'did @youngertv really make a @camerondiaz reference to @hilaryduff ? <lh>',
#  "questioning if ur beats are good enough to sell online? i'll save u some time..they're not! quit looking for that quick 💰💰💰 basic <lh>",
#  'every now and then, people come along and surprise you with their support. <lh>',
#  'tried that la croix sparkling water for the first time today, and lemme tell you...it’s decent opinions wild <lh>',
#  'god bless my parents for everything they do for me and my daughters💞grateful <lh>',
#  '@liberallisa @tucsonblonde kushner is about as jewish as santa claus! <lh>',
#  'corinthians : ( of ) for we also are weak in him, but in dealing with you we will live with him by the power of god. <lh>',
#  '@official_brfc @wolves the guy " not interfering with play" was stood yards directly in front of slocombe - <lh>',
#  'small businesses will dominate big brands through emotional connections! and social media is to thank for that! buildyourbrand <lh> eat',
#  '@potus is it hard for you to call them "white supremacist terrorists", because you have one pulling your weak strings? presidentbannon <lh>',
#  'most people want it easy - you gotta believe in yourself. <lh>',
#  'all these "friends" hit up my line like "yes girl you can talk to me" but i cant because you only text me when there is wrong <lh> 💔💔',
#  'againstthelaw truly harrowing to hear stories of state persecution against gay men. so thankful the rights & liberty i have today! <lh>',
#  "....don't let tragedy be the string that pulls us together. for every lesson not learned, will be repeated. charlottesville harvey <lh>",
#  'leadership in action from a @dpd_uk driver at . pm today near turners hill (crawley). helped about drivers. leadership <lh>',
#  'okay but like really i do not handle standstill traffic well. <lh>',
#  'great now i can write poems here on twitter too yahooo 🕺🏻🎉🎊 😬😎 <lh>',
#  '"how wonderful! how wonderful! all things are perfect, exactly as they are." ~ buddha awareness <lh>',
#  'confessyourunpopularopinion all nations fail. don\'t want to be deceived? focus on what matters. "my kingdom is not of this world..." <lh>',
#  "i'm in cardiff, and there's men holding hands! <lh>",
#  'i prayed for i️t and i got i️t 🙏🏽 <lh>',
#  'this is nerve-racking. even my dream gives me the jitters. 😨😨😨 helpmegod <lh> bahalanasigod',
#  '@jillorban so are we northerners--always humoured by the antics of southernsnow <lh> up!',
#  'thanks @realdonaldtrump for guaranteeing we get hillary, bernie or kamala harris as prez in . <lh>',
#  "@joelhashtagking i hate to tell you this, but that ain't bread crumbs. <lh>",
# ...
#  'back from cinema now supper and wait for @itvimaceleb <lh>',
#  'i love watching people trying to defend the incest of danny and jon but hated cerci and jamie doublestandards got <lh>',
#  'excellent work involving a couple dozen officers, four hours of negotiation, some swat help, and one in custody! lpd goodteamwork <lh>',
#  "horrible day! rip @tompetty, prayersforvegas and @whoopigoldberg and @mileycyrus still haven't left the us as promised due to @potus! <lh>",
#  'the good lord is going to have to help me today to keep me from walking out and not coming back notmydreamjob <lh>',
#  "@vp clearly you're trying to red herring the russia trump investigation. <lh>",
#  'being cannot be said to be true to say that there should be either true or false. <lh>',
#  '@foxnews let’s all hope the nra has enough blood money to pay for all those “thoughts and prayers” coming from the gop. <lh>',
#  "prepping @violetthewhale books & stickers to send later this week...except those with t-shirts (sorry. those aren't due til th) <lh>",
#  'pink hair looks so good in him and plus he the back ground perfectly matches rapmonster bts <lh>',
#  "oh gosh 🤦🏾\u200d♀️ molly you're a lost cause ... <lh>",
#  "don't post boring content for the sake of it, have something to say and try and throw in some imagination. <lh> <lh>",
#  'how interesting that instead if coming to save him, jesus told peter to step out of the boat and into the storm. <lh> <lh>',
#  '@n_ataha he is the most loyal one there will ever be <lh>',
#  'i gave $ to gas my car and got gassed for $ instead 😂 <lh>',
#  'my yoga coach is a psycho she told us at the end to laugh out loud for no reason and told us if you cannot do this you have a problem <lh>',
#  'my stuff are all set for our prenup shoot! yeeeey!! 😍 <lh>',
#  "excited to reveal i'm headed to @eleaguetv this weekend! new city, new opportunity, and working with the best in esports. <lh>",
#  'proud of how the boys , love the signings , morata and rudiger are class <lh>',
#  "don't forget fata which z still being run under the notorious fcr- a different set of laws from rest of pakistan. <lh> independence day.",
#  'why is there strangers at my house 😭 <lh>',
#  '@miss_fleur personally id wait til friday <lh>',
#  'about to bet what little money i have left today on the races in an attempt to make back all the money i spent in vegas <lh>',
#  'thank you lord for a beautiful day i am blessed to be alive <lh>',
#  'til @billsimmons can’t do math. -= he came up with and later <lh>',
#  'what a long day at the office , so glad im on my way home to relax with <lh> <lh>',
#  'when your boyfriend “wins” banda ms tickets but right when they are about take his info @zonamx hangs up. <lh> 😡',
#  'after years im finally gonna dye my hair 😁😁😁 needachange <lh>',
#  "@miniminter i thought you'd be used to playing with yourself by now solosimon <lh>",
#  '@chefjoseandres @erinemooney thank you for all you are doing to help feed the people of pr🙏 humanitarian <lh> helppuertorico',
#  "@realdonaldtrump had enough time to tell his repugnant base that he didn't mean what he was going to say today. <lh> domesticterrorism",
#  '@carajaderose i thought potato scallop was the same thing as potato bake??????????????? <lh>',
#  'fun fact! did you know what the word "bride" comes from an old proto-german word meaning "to cook". <lh> <lh> besmartaboutlove',
#  '@mcdonalds nothing better then piece chicken nugget on a late night after expecting . <lh>',
#  'if our country can get together to see an eclipse then we can come together to love one another... eclipsesolar <lh> ❤️🙏🏼🙌🏼',
#  'not male reporter in camnewton presser stopped him as he belittled a female reporter. but plenty of them capitalized on the story <lh>',
#  '@claytravis paris was the son of king priam. he is kinda like jay cutler. <lh>',
#  'can you please mind your own life! <lh>',
#  'this am a man was standing outside the pharmacy in cowboy boots, a tube top, &amp; a diaper- it’s gonna be a long one today <lh>',
#  'say what you want about millennial‘s, but at least they’re tolerant! millennials ourfuture <lh>',
#  'at a graduation & i saw how proud a wife was of her husband when he was called. <lh>',
#  'sitting out on the porch at am .. good music, cold beer and a storm coming in. <lh>',
#  'alabamaelection, good move. but how did % of white women approve of a pedophile? <lh>',
#  '@brischh you there throwing away ticketsand i here toting i cant go and have to work <lh>',
#  '@nyknicks @kporzee why don’t he just say, i’m not playing.... <lh>',
#  '@ddlovato happy birthday baby!!! thanks for everything ! good day and i love you so much 🎉🎉🎉❤️🎉🎉 happybirthdaydemi baby <lh> goodgirl',
#  '@tiffanykingya i just discovered that this morning! onthethday... <lh>',
#  'my little peanut logan is being stubborn😩.... <lh>',
#  'what is it about the song "ramblin man" that makes the baby so happy newdad <lh>',
#  "went to palms last night and saw the kingsman . i slept hours and now i'm in uber on my way to venetian to play poker. <lh>",
#  'on a @southernrailuk train to gatwick with no dedicated place to put luggage! i suppose no one wants to take bags to an airport! <lh>',
#  'good afternoon...betheone that makes due with what you have! <lh>',
#  '"the lord upholdeth all that fall, and raiseth up all those that be bowed down." ~psalms : <lh>',
#  "now i'm blocked from log in again! -d time in past hours! <lh>",
#  "fuck in weeks i'm actually gonna work when the store is open <lh>",
#  'believe in god and in yourself & the world will be at your feet. <lh>',
#  'bought some wingstop and i told le bae "i don\'t want no more you can have it" she fucking ate it. people say shit when they full. <lh>',
#  '“he is before all things and in him all things hold together.” | colossians :, niv <lh> <lh>',
#  '@cheetosd when u use a glitch to boost ur self esteem <lh>',
#  'that awkward moment when you get called antiamerican for literally quoting the constitution. 😂 <lh> vetsresist',
#  'god gives us dreams a size too big so that we can grow into them. motivation <lh> <lh>',
#  'yo the gpd got costumes on this year <lh>',
#  '@ddlovato tellmeyoulove me has the best songs if you’re going through a breakup <lh> dontdoitformeanymore',
#  'welcome to the best sunday of @jbarfoot <lh>',
#  'its hard sometimes to realize the problem is you and maybe not them or maybe just a little them ... but mostly you ... realization <lh>',
#  'homeless on our street camps on sofas left behind when people move. i call the city to remove abandoned items. making man sofa-less <lh>',
#  'when your boss says "hey alexis i left you something on your desk " 😇. <lh>',
#  "@probablynotymo hahahahahah let's pick one together pls i don't wanna be <lh>",
#  'hahahhaha all life does is deal me shit cards. <lh>',
#  'one on every block in rhody not a single one here <lh>',
#  'if alex smith can throw around the patriots defense imagine what drew brees will do next week <lh>',
#  'o yeah i did like lawerence but now .. nah <lh>',
#  "netflix your deathnote movie is this years m night's avatar. i'm very disappointed. who thought this was a good idea? <lh>",
#  '@jimmykimmel & the rest of usa understand @billcassidy is a lying sack of crap working to kill americans <lh> trumpcare',
#  'cant come up with healthcare plan that can pass? just scrap what exists in the hopes you can figure it out. <lh> whereareourleaders',
#  'just came from seeing @scaramucci talk at the cambridge union. not many fireworks from the audience :( a bit disappointing <lh>',
#  'the moment i planned to keep strong. god showed me. i at least reached one person. <lh>',
#  'i’m all about ppl feelin themselves when they’re dancing but sometimes... <lh>',
#  'to lexy a special day and a special person. when your daughter passes the florida bar. thank you @carleton_u @stetsonlaw <lh> <lh>',
#  'step one in dealing with someone who is "in an open marriage"---here it from both parties first! *sigh* <lh> <lh>',
#  'found a job where the day goes faster than the lunch break <lh>',
#  'sitting in @starbucks next to a year-old who\'s reading "the wealth of nations." <lh> hopeforourcountry',
#  "so loyal you don't even realise you're lying. <lh>",
#  "i just embarrassed the fuck out of myself and i can't bare to stay in my house tonight someone make plans with me <lh>",
#  'just realized i put "you\'re" on my sc instead of "your"..... <lh>',
#  'just saw a whale in the bay while crossing the golden gate <lh>',
#  'yep and he did it! i’m exicited to@see him do it again! <lh>',
#  '@jasminemix_llc please please please let it be kellyanne conway kac please. i might even go back to church if that happens!!!! <lh>',
#  'just found our first dance song ! 😳😍❤️ andd it just so happens it was released this year on our future wedding date (oct.) itsasign <lh>',
#  '@realdonaldtrump this coming after @stephencurry declined your invite you settled for @nhl <lh>',
#  'thank you for all the birthday wishes everyone! much love ❤️ <lh>',
#  'thoughts: every time you give in to a fear, it becomes more intense....because <lh> grows!',
#  "hours left to make sure everything is packed and loaded then it's @poacher here we come. <lh> beprepared",
#  'waking up on a sunday am; realizing that god is good & we are stillwinning maga <lh>',
#  "i can't believe simon vs the homosapien agenda is getting a movie, so <lh>",
#  'it took me years of my life for somebody to come into my life and teach me how to... not give a fuck about what others think. 🙃 <lh>',
#  'shout out to all my friends that never got to go on a magical fantasy adventure at after some tragedy. anime lied. betrayal anime <lh>',
#  '@jimbrown terrible 🙈. i’m growing a ponytail n going tar jump about like a dafty. <lh>',
#  "when you finished watching the whole series of willandgrace (again) @willandgrace - and now you're <lh> 😩😭stan",
#  "like i'm happy and in my feelings but i'm crying . lol <lh>",
#  '"in his days shall the righteous flourish; and abundance of peace so long as the moon endureth." ~psalms : <lh>',
#  '@ehsaych if my girlfriend dumps me, you can have the ticket. <lh>',
#  'happy for cardi b and offset the love is genuine you can tale <lh>',
#  'i’m hungry af ! but the laziness outweighing it 😭 <lh>',
#  'thanksgiving meals, a hunt and online shopping later <lh>',
#  '@alisonmitchell loved this alison, you guys have the best job in the world <lh>',
#  "i honestly hate waking up early but once i'm up, i'm in the happiest mood. <lh>",
#  "she's my maximum risk and she knows herself. unice <lh>",
#  'i want to stream but i really don’t want to play that water temple <lh>',
#  '"so that he forsook the tabernacle of shiloh, the tent which he placed among men;" ~psalms : <lh>',
#  'psalm : surely i have behaved and quieted myself, as a child that is weaned of his mother: my soul is even as a weaned child. <lh>',
#  '@imrankhanpti you are a blessing to pakistan. may allah give you long life and good health. you are the <lh>',
#  "@officedepot your online live chat assistance needs some work. i have been on this chat for min and the problem still isn't resolved <lh>",
#  'the beauty of a woman must be seen from in her eyes, because that is the doorway to her heart, the place where love resides. <lh> <lh> ❤',
#  "the world 🤣if you have a man genitalia use the men's wc, likewise for women. i for one wouldn't install extra bathrooms. stopit <lh>",
#  "sundays are such busy days.....enjoyable but busy...but mondays aren't so bad anymore! retiredandlovingit <lh>",
#  '@blacchyna you are an amazing artist and model <lh>',
#  'thankyou jesus for waking me up and helping me fall asleep on time <lh>',
#  'i know mcgregor said he was just tired but maybe a little punchy. what does "i made him fight like a mexican mean" <lh>',
#  'i was dreaming about lot of things. it was tatto, new room, better phone- doesnt matter. it was stupid things. i got it. <lh>',
#  'too many believe we must be harsh toward sinners, but peter tells us to love them. love covers a multitude of sins. peter : <lh>',
#  'yo! my bestie is driving from her house to bring me food because i was hungry! <lh> 🙌🏾😭',
#  'love waking up to my baby girl 🙏 <lh>',
#  '"am i watching a trainwreck? i wanna see a trainwreckkkkk...." -mark on the ama\'s 🤦🏼\u200d♂️ amas amas nightoftoomanystars <lh>',
#  '@presstv when are they not getting attacked! when will this barbaric act stop and when will people realise they are human too <lh>',
#  "hi everyone hope y'all enjoying your day. 😘😘 goodvibesonly <lh>",
#  "when you find out you're studying abroad next summer in ecuador! multiculturalcounseling <lh>",
#  "when you stop worrying and just breathe knowing it's going to work out, it does! loa <lh> 🙏❤️",
#  '"and greetings in the markets, and to be called of men, rabbi, rabbi." ~matthew : <lh>',
#  '@sadamsrp @matthewfsmith did you see any armed group there ? <lh>',
#  '@donaldjtrumpjr @ivankatrump too bad tiffany is the one who has been cast aside <lh>',
#  'just heard @thebugzymalone live lounge of @eminem stan. if i was wearing a hat i tip it too you my friend. <lh>',
#  '@pink you truly are a musical genius. new album is of the charts! 😍 can’t wait for the tour... 🎧🎶 <lh> beautifultrauma',
#  '"love has to be general, honor all men because in honor you love." - @edlaks <lh> thetriunecentre',
#  "just finished @joshmalerman's birdbox and it was so great to have some michigan in a book fit for halloween petoskey artfair <lh>",
#  'usually your biggest trials come right before your biggest breakthroughs. keep pushing on in god! <lh>',
#  'unusual time but british motogp is about to get going. <lh>',
#  '@airbagon the song choice you made for your project showed i still influence your taste in music 😊 <lh>',
#  'well i was that bored that i braved the weather, got my mountain bike out, set off on a mile ride and ended up in the pub after <lh>',
#  '@gregabbott_tx funny how not one good guy with a gun stopped the bad guy with a gun, huh, abbott?! <lh>',
#  'i just hit a lick at portillo’s lol. free food. <lh>',
#  "shout out to the cop who didn't give me the speeding ticket. <lh>",
#  "just ate a baked a hotpocket and didn't just put it in the microwave. adulthood <lh>",
#  "@kellyannepolls shouldn't you be attacking hillary clinton? kellyanne conway political gold digger <lh>",
#  "i've been on cloud for weeks now and i don't see myself coming down any time soon 😍 <lh>",
#  'varsity will face st. henry @ dixie @pm on friday. we have lots to address & fix before this game but i really like my team! <lh> bfsb',
#  '@mattleonkyw remember when @colincowherd ripped all of philadelphia basically over andy reid? has kc won a game since? <lh>',
#  'another video almost done and already got tomorrows video planned out! <lh>',
#  '@deadmansfingers mmm yes please dreaming off a decent cuba libra here 🍹 rum 🍀 <lh> 💀',
#  '@sr_drivinschool i’m the one wearing a dress. come find me, i need friends 😆 <lh>',
#  "it's a treat to get sick right before halloween. <lh>",
#  '@sarahsmile_ i never step on them anyway. i always pick them up with a paper towel and set them outside gentle <lh>',
#  'if you fail in something and above all that notinterested to do it. just dontdoit.your life is <lh> withoutit.',
#  'the tennessee governor says he will reimplement work requirements before people can get snap benefits. poverty food <lh> assistance',
#  'tfw the swerving, honking driver is not crazy but trying to tell you your wallet just flew off the roof of your car <lh>',
#  'this morning i cried about tiny goats and listened to some of my favorite s tunes w my bf <lh>',
#  'nothing stirs flibbertigibbets into frenzied fiddlefests like symbols over substance -- as in a flag over a constitution. takeaknee <lh>',
#  'dakota and i just hopped outa bed like christmas morning to see two fire trucks pull up to our neighbors. <lh> thefuckishappening',
#  'people are real stingy with they blessings ,you be asking for simple shit and they rather ignore u than tell u <lh>',
#  'struggling with things right now and i appreciate having people to talk to about it <lh>',
#  'मैं_भारत_बोल_रहा_हूँ qki hamare pm flight mood me hai .... esse achha to silent tha <lh> amarnathyatra',
#  ...]

# %%
# Initialise the vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words=stopwords.words('english'))

# %%
# Fit and transform train_processed dataframe
X = vectorizer.fit_transform(train_processed)

# %%
# Split the train_processed dataframe into train and validation dataframes
X_train, X_val, y_train, y_val = train_test_split(X, y_train, test_size=0.2, random_state=42)

# %%
# Initialise the RandomForest model 
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Train the model 
model.fit(X_train, y_train)
# Out:
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Fan Kai Jie\AppData\Local\Temp\ipykernel_29804\180087699.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# RandomForestClassifier(random_state=42)

# %%
# Make predictions with validation data first
predictions = model.predict(X_val)

# %%
# Evaluate the model
print(classification_report(y_val, predictions))
# Out:
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#               precision    recall  f1-score   support
#
#        anger       0.43      0.10      0.16      7946
# anticipation       0.59      0.48      0.53     49984
#      disgust       0.38      0.26      0.31     27669
#         fear       0.64      0.28      0.39     12846
#          joy       0.49      0.81      0.61    102943
#      sadness       0.47      0.38      0.42     38745
#     surprise       0.58      0.17      0.26      9816
#        trust       0.54      0.26      0.35     41164
#
#     accuracy                           0.50    291113
#    macro avg       0.52      0.34      0.38    291113
# weighted avg       0.51      0.50      0.47    291113

# %%
# As what I did to train_processed dataframe, I fit and transform test_processed dataframe as well
X_test = vectorizer.fit_transform(test_processed)

# %%
# Make predictions with test data
actual_pred = model.predict(X_test)

# %%
# Visualise actual_pred array
actual_pred
# Out:
# array(['sadness', 'trust', 'sadness', ..., 'disgust', 'joy', 'sadness'],
#       dtype=object)

# %%
# Check if it is the expected output, as after writing predcitions into csv file, the word is split up into columns. 
# For example, instead of 'sadness', it wrote 's', 'a', 'd', 'n', 'e', 's', 's' into the csv file.

actual_pred[0]
# Out:
# 'sadness'

# %%
# Separate out the tweet_id
test_id = test['tweet_id']

# %%
# Check if test_id is in the format I want
list(test_id)
# Out:
# ['0x28b412',
#  '0x2de201',
#  '0x218443',
#  '0x2939d5',
#  '0x26289a',
#  '0x31c6e0',
#  '0x32edee',
#  '0x3714ee',
#  '0x235628',
#  '0x283024',
#  '0x25dcd8',
#  '0x33df6e',
#  '0x2d6cb6',
#  '0x21d36a',
#  '0x34fc3e',
#  '0x338b96',
#  '0x38895c',
#  '0x260d2b',
#  '0x38c20a',
#  '0x21ee14',
#  '0x245e5b',
#  '0x2fa1a8',
#  '0x340bc5',
#  '0x21114e',
#  '0x32d429',
#  '0x380533',
#  '0x2e59dd',
#  '0x32de62',
#  '0x2f2f42',
#  '0x2b3f7a',
#  '0x1f0f0d',
#  '0x1e0006',
#  '0x24c180',
#  '0x2c0cbb',
#  '0x2b5304',
#  '0x2213f8',
#  '0x25ae82',
#  '0x1dcc6b',
#  '0x317bd3',
#  '0x366e92',
#  '0x3186fc',
#  '0x2e190e',
#  '0x2158b8',
#  '0x3204bd',
#  '0x2ec3b8',
#  '0x203e91',
#  '0x2d72d4',
#  '0x20e76d',
#  '0x2255e2',
#  '0x1d6edf',
#  '0x2f07b4',
#  '0x20f8f2',
#  '0x36627d',
#  '0x1d863a',
#  '0x1dc4b5',
#  '0x318056',
#  '0x2d4d7f',
#  '0x24afcd',
#  '0x2c9398',
#  '0x22d1ce',
#  '0x2940be',
#  '0x32b37a',
#  '0x1e52b7',
#  '0x1cf9f5',
#  '0x2b0197',
#  '0x23c767',
#  '0x27c6e5',
#  '0x1ed702',
#  '0x2b4cf6',
#  '0x22e505',
#  '0x20410d',
#  '0x1fbc44',
#  '0x27485a',
#  '0x33bd17',
#  '0x295aed',
#  '0x2dea64',
#  '0x3160c7',
#  '0x349bab',
#  '0x2637e6',
#  '0x1d98b2',
#  '0x273eb4',
#  '0x22ab2b',
#  '0x214b93',
#  '0x3627d9',
#  '0x2ccae2',
#  '0x1e9770',
#  '0x26f575',
#  '0x23ce28',
#  '0x33c1fc',
#  '0x20baa4',
#  '0x2d46e2',
#  '0x37215c',
#  '0x3262c4',
#  '0x329b0e',
#  '0x215c11',
#  '0x25a1b4',
#  '0x2276fe',
#  '0x268d8a',
#  '0x25134f',
#  '0x1e3b93',
#  '0x2051e7',
#  '0x1f0531',
#  '0x223e85',
#  '0x1fe3c3',
#  '0x363e48',
#  '0x1e348d',
#  '0x2cb892',
#  '0x290755',
#  '0x20a163',
#  '0x32030b',
#  '0x2ef628',
#  '0x3648ba',
#  '0x2ffefa',
#  '0x1cbd25',
#  '0x2bc6dd',
#  '0x2e0f4f',
#  '0x269f58',
#  '0x2db232',
#  '0x295d38',
#  '0x2d9f84',
#  '0x22588d',
#  '0x24d64f',
#  '0x35d38e',
#  '0x361bc7',
#  '0x2e3fa7',
#  '0x261019',
#  '0x30349b',
#  '0x2a708a',
#  '0x2e5841',
#  '0x37677f',
#  '0x32bba6',
#  '0x2aa616',
#  '0x30352a',
#  '0x2a869a',
#  '0x2f2cf2',
#  '0x20637c',
#  '0x3821a0',
#  '0x26daaa',
#  '0x2aee7c',
#  '0x268b68',
#  '0x34a1c9',
#  '0x342aaa',
#  '0x285717',
#  '0x306f6c',
#  '0x376bb7',
#  '0x34a527',
#  '0x259084',
#  '0x23eb85',
#  '0x28b03b',
#  '0x383aa7',
#  '0x211e20',
#  '0x30b0a3',
#  '0x1dbe62',
#  '0x1fecfa',
#  '0x285be5',
#  '0x335392',
#  '0x1d0767',
#  '0x31c71a',
#  '0x29fa9c',
#  '0x25adaa',
#  '0x2fcea3',
#  '0x22503b',
#  '0x27d42f',
#  '0x374197',
#  '0x38f845',
#  '0x324e66',
#  '0x32416a',
#  '0x251ee1',
#  '0x219101',
#  '0x38202a',
#  '0x212a8e',
#  '0x32804c',
#  '0x22b823',
#  '0x35e142',
#  '0x32d7f8',
#  '0x2667f7',
#  '0x2a9e7f',
#  '0x1dc757',
#  '0x37c305',
#  '0x26a251',
#  '0x211c1d',
#  '0x32d8e6',
#  '0x312a6e',
#  '0x37bd55',
#  '0x27a190',
#  '0x2e0796',
#  '0x34bd65',
#  '0x20e850',
#  '0x286248',
#  '0x381ff7',
#  '0x2f7e36',
#  '0x2646ad',
#  '0x2090be',
#  '0x2a80ca',
#  '0x35f889',
#  '0x34dcff',
#  '0x3204f0',
#  '0x296ecf',
#  '0x34398a',
#  '0x2a6fe5',
#  '0x2fa446',
#  '0x369e1c',
#  '0x35c038',
#  '0x2c5137',
#  '0x2ba0b2',
#  '0x237734',
#  '0x3480fa',
#  '0x2a7731',
#  '0x350de3',
#  '0x339b66',
#  '0x2f038e',
#  '0x29a8ca',
#  '0x3007c0',
#  '0x23878d',
#  '0x20aeb9',
#  '0x26013d',
#  '0x2e0a8a',
#  '0x31a468',
#  '0x2e549c',
#  '0x343fb1',
#  '0x22a61b',
#  '0x2f43fc',
#  '0x272d18',
#  '0x1e41bf',
#  '0x2a58f5',
#  '0x2a83c9',
#  '0x227bce',
#  '0x1d7589',
#  '0x2c54b6',
#  '0x242336',
#  '0x1f7c14',
#  '0x30fe7d',
#  '0x3805a5',
#  '0x248ff6',
#  '0x284591',
#  '0x24b467',
#  '0x34004f',
#  '0x34bb69',
#  '0x2f7502',
#  '0x2f6d7a',
#  '0x382e5c',
#  '0x1cde6b',
#  '0x1e1417',
#  '0x372a79',
#  '0x29d64a',
#  '0x35897b',
#  '0x2052cc',
#  '0x34951b',
#  '0x2a9d2f',
#  '0x282d96',
#  '0x23b3e0',
#  '0x20fe87',
#  '0x24e24f',
#  '0x3683ad',
#  '0x280ced',
#  '0x2ff84c',
#  '0x1dbbda',
#  '0x2fe4c0',
#  '0x227a79',
#  '0x28bde2',
#  '0x2deef9',
#  '0x234775',
#  '0x2e0a44',
#  '0x20605d',
#  '0x24ad3a',
#  '0x1c9f27',
#  '0x1fce9a',
#  '0x326a0a',
#  '0x329cdb',
#  '0x34cb02',
#  '0x2ee360',
#  '0x230691',
#  '0x314212',
#  '0x2a6b77',
#  '0x3557de',
#  '0x2eea99',
#  '0x2e1b86',
#  '0x23f1ae',
#  '0x26af59',
#  '0x222996',
#  '0x345771',
#  '0x2c8ee1',
#  '0x26967e',
#  '0x20a9fe',
#  '0x21b4ce',
#  '0x240d00',
#  '0x25a389',
#  '0x37b9f3',
#  '0x36fe83',
#  '0x30f8ed',
#  '0x22fd1e',
#  '0x358049',
#  '0x21eab3',
#  '0x286aaa',
#  '0x300deb',
#  '0x25b5dc',
#  '0x21b056',
#  '0x28336d',
#  '0x37e98e',
#  '0x297d09',
#  '0x2c29f7',
#  '0x1d9bca',
#  '0x2f8c76',
#  '0x22c600',
#  '0x239442',
#  '0x1e1c2c',
#  '0x1ea6d5',
#  '0x2345b6',
#  '0x238ca4',
#  '0x37d114',
#  '0x32d785',
#  '0x235645',
#  '0x376745',
#  '0x369fef',
#  '0x3264e7',
#  '0x237ed3',
#  '0x31c806',
#  '0x205e5f',
#  '0x253b30',
#  '0x2156a6',
#  '0x33149e',
#  '0x245d23',
#  '0x2f3344',
#  '0x33372a',
#  '0x219c3f',
#  '0x35afb4',
#  '0x3619b8',
#  '0x363ad4',
#  '0x3897df',
#  '0x25f8b3',
#  '0x1daad4',
#  '0x21545d',
#  '0x1faf28',
#  '0x38547b',
#  '0x34e0e9',
#  '0x35f619',
#  '0x22b4b9',
#  '0x3728b5',
#  '0x3096d5',
#  '0x1e3495',
#  '0x1fef4f',
#  '0x1dc0b9',
#  '0x25914b',
#  '0x1ed499',
#  '0x318436',
#  '0x2e9b22',
#  '0x254d32',
#  '0x260114',
#  '0x2744a8',
#  '0x2f6602',
#  '0x25e35d',
#  '0x2301b8',
#  '0x2fc688',
#  '0x376a33',
#  '0x252435',
#  '0x21f733',
#  '0x2515e4',
#  '0x2809c0',
#  '0x2011bc',
#  '0x261122',
#  '0x28c4b0',
#  '0x2543dc',
#  '0x2b8c00',
#  '0x1fda77',
#  '0x25163b',
#  '0x379ddd',
#  '0x313b29',
#  '0x30532b',
#  '0x367138',
#  '0x2a02aa',
#  '0x2ab988',
#  '0x34f5ec',
#  '0x2fc40e',
#  '0x367e2a',
#  '0x228982',
#  '0x32ef03',
#  '0x31e269',
#  '0x2d2093',
#  '0x3772cd',
#  '0x31c6c4',
#  '0x3419bf',
#  '0x2c13de',
#  '0x319150',
#  '0x234354',
#  '0x33733c',
#  '0x2e8bbb',
#  '0x2ea72e',
#  '0x31f42c',
#  '0x1c9e26',
#  '0x21ee9c',
#  '0x30fbe4',
#  '0x2e1c2e',
#  '0x2b6341',
#  '0x2036ff',
#  '0x26ef26',
#  '0x1d6f97',
#  '0x313436',
#  '0x33dd8b',
#  '0x1ecab2',
#  '0x1dac19',
#  '0x331684',
#  '0x2ea130',
#  '0x2ee71b',
#  '0x2c7415',
#  '0x1d1955',
#  '0x259d26',
#  '0x2f5e3d',
#  '0x1f5e83',
#  '0x33de87',
#  '0x35ca16',
#  '0x231d80',
#  '0x26060f',
#  '0x29b733',
#  '0x35ab16',
#  '0x20566d',
#  '0x240765',
#  '0x2de464',
#  '0x2a6ce4',
#  '0x2948ad',
#  '0x217b7a',
#  '0x35dbe4',
#  '0x1e3d4f',
#  '0x206bab',
#  '0x24495f',
#  '0x1dbc14',
#  '0x33ff9e',
#  '0x277434',
#  '0x3333e4',
#  '0x33094f',
#  '0x38c708',
#  '0x37eef3',
#  '0x2da924',
#  '0x3774f9',
#  '0x352e0b',
#  '0x2b1a5a',
#  '0x1eaeaa',
#  '0x24b6cc',
#  '0x23037e',
#  '0x374c23',
#  '0x286ee6',
#  '0x273723',
#  '0x2f7b19',
#  '0x310e41',
#  '0x307570',
#  '0x2f8301',
#  '0x38b1c6',
#  '0x1d3364',
#  '0x2ef381',
#  '0x385acc',
#  '0x2f2b49',
#  '0x2134c9',
#  '0x23067f',
#  '0x36ecce',
#  '0x276625',
#  '0x255644',
#  '0x271be3',
#  '0x2d75d2',
#  '0x3464a0',
#  '0x36f6df',
#  '0x2e9e11',
#  '0x2a6d39',
#  '0x2a16bc',
#  '0x315e01',
#  '0x350251',
#  '0x37e0aa',
#  '0x353996',
#  '0x2ee337',
#  '0x21e6b0',
#  '0x34ccc6',
#  '0x36134d',
#  '0x2dcb03',
#  '0x1ccff6',
#  '0x36bd5c',
#  '0x33a063',
#  '0x2aa407',
#  '0x37657f',
#  '0x320e35',
#  '0x1f6594',
#  '0x350fe5',
#  '0x2858cf',
#  '0x3563ab',
#  '0x1ccf3c',
#  '0x28eca8',
#  '0x29f994',
#  '0x240a74',
#  '0x2f4cc8',
#  '0x2d9cdd',
#  '0x1f82e9',
#  '0x28ab81',
#  '0x2947d4',
#  '0x24b02a',
#  '0x350eb9',
#  '0x2e7cc9',
#  '0x2ace9d',
#  '0x1e378b',
#  '0x35523f',
#  '0x1e2ab9',
#  '0x2d8c26',
#  '0x21acb7',
#  '0x37e1e2',
#  '0x372160',
#  '0x213180',
#  '0x1dd517',
#  '0x257890',
#  '0x27537a',
#  '0x2e6dc9',
#  '0x3164e0',
#  '0x21eff3',
#  '0x25151f',
#  '0x2556aa',
#  '0x33258a',
#  '0x2b6d87',
#  '0x1ca474',
#  '0x25661b',
#  '0x387f83',
#  '0x31a318',
#  '0x1e6fbb',
#  '0x1d2d23',
#  '0x290608',
#  '0x31420d',
#  '0x3701a5',
#  '0x22681b',
#  '0x36cfdc',
#  '0x20f62d',
#  '0x32a06c',
#  '0x316e1b',
#  '0x330f91',
#  '0x2e3909',
#  '0x22b078',
#  '0x228caa',
#  '0x235d94',
#  '0x23f896',
#  '0x22f54f',
#  '0x34226e',
#  '0x25937d',
#  '0x31ab2a',
#  '0x34f0f8',
#  '0x384123',
#  '0x349654',
#  '0x219fd0',
#  '0x308961',
#  '0x21eb11',
#  '0x27eeeb',
#  '0x1c8848',
#  '0x2abb2f',
#  '0x2916ed',
#  '0x298d07',
#  '0x2fb6dd',
#  '0x2abea3',
#  '0x345329',
#  '0x301546',
#  '0x204a2f',
#  '0x22a49c',
#  '0x2f31af',
#  '0x35e05b',
#  '0x2f7c2b',
#  '0x38e0eb',
#  '0x226dce',
#  '0x1e41cb',
#  '0x1eee71',
#  '0x35ab87',
#  '0x283b2a',
#  '0x2cf5f8',
#  '0x1ca130',
#  '0x2b6fda',
#  '0x1d3485',
#  '0x3504bd',
#  '0x2e45e6',
#  '0x290f72',
#  '0x35c179',
#  '0x2205b3',
#  '0x341595',
#  '0x334195',
#  '0x2e85f8',
#  '0x33f50a',
#  '0x27023e',
#  '0x1f8bc9',
#  '0x2fec46',
#  '0x38be5b',
#  '0x253f74',
#  '0x1ceea1',
#  '0x2fd9e3',
#  '0x2f33f7',
#  '0x352af5',
#  '0x345a38',
#  '0x28e6e5',
#  '0x34ff6e',
#  '0x2ec8fb',
#  '0x2a2943',
#  '0x36027a',
#  '0x25b666',
#  '0x253352',
#  '0x330ade',
#  '0x2a64b9',
#  '0x25ce53',
#  '0x28b457',
#  '0x25886b',
#  '0x2f08b3',
#  '0x1df9ff',
#  '0x2947a1',
#  '0x25d6b5',
#  '0x2c5ce9',
#  '0x3475c2',
#  '0x345fd3',
#  '0x28fd34',
#  '0x201a83',
#  '0x2d1af0',
#  '0x2817a8',
#  '0x26c47b',
#  '0x279c7a',
#  '0x3342d2',
#  '0x31ff1a',
#  '0x277b3e',
#  '0x238195',
#  '0x2dc85e',
#  '0x379076',
#  '0x23ba48',
#  '0x2f8326',
#  '0x357267',
#  '0x2d2b0b',
#  '0x2c3c2c',
#  '0x387a1d',
#  '0x21680a',
#  '0x1d8cc0',
#  '0x1de32a',
#  '0x2f1bb1',
#  '0x238d23',
#  '0x2ada07',
#  '0x2d2c01',
#  '0x22f4a7',
#  '0x2edaa6',
#  '0x377520',
#  '0x3264d4',
#  '0x32e70d',
#  '0x20f5c3',
#  '0x32b12b',
#  '0x1d916e',
#  '0x2ec716',
#  '0x2eb494',
#  '0x2fe981',
#  '0x35201c',
#  '0x1e31da',
#  '0x31528e',
#  '0x298852',
#  '0x21aac3',
#  '0x26c493',
#  '0x251f84',
#  '0x340c2a',
#  '0x326c18',
#  '0x1e64a6',
#  '0x35a6c6',
#  '0x2921f6',
#  '0x3614b7',
#  '0x2569cb',
#  '0x28f66e',
#  '0x32613a',
#  '0x22b3e0',
#  '0x2a6dc4',
#  '0x26d830',
#  '0x25f6ba',
#  '0x1cc348',
#  '0x2e0799',
#  '0x36c8e4',
#  '0x2cc7fa',
#  '0x290f17',
#  '0x1db568',
#  '0x2e512c',
#  '0x1fa0b0',
#  '0x28e4fb',
#  '0x2fb3ce',
#  '0x313694',
#  '0x2310f3',
#  '0x33f4f0',
#  '0x2adaaa',
#  '0x22cfde',
#  '0x21d3cc',
#  '0x3402f0',
#  '0x3095eb',
#  '0x2a04ca',
#  '0x2f8ea1',
#  '0x364348',
#  '0x350bc9',
#  '0x27bf77',
#  '0x243520',
#  '0x2ccc2c',
#  '0x2fa8d8',
#  '0x1ed7c6',
#  '0x31be22',
#  '0x2c7689',
#  '0x264148',
#  '0x345801',
#  '0x1f970d',
#  '0x227826',
#  '0x31eb70',
#  '0x21953d',
#  '0x38dae4',
#  '0x23d1b0',
#  '0x230bfb',
#  '0x35d8dd',
#  '0x2f3dda',
#  '0x26f4dc',
#  '0x1ebfda',
#  '0x2092ca',
#  '0x224e05',
#  '0x25599a',
#  '0x1d62e5',
#  '0x278477',
#  '0x2f1315',
#  '0x38f974',
#  '0x34fad3',
#  '0x364eeb',
#  '0x383930',
#  '0x1f1f7c',
#  '0x37476b',
#  '0x2b1904',
#  '0x2a6ce6',
#  '0x282eea',
#  '0x245afc',
#  '0x2f47ef',
#  '0x23f28a',
#  '0x33ea4c',
#  '0x20f4b3',
#  '0x319e5e',
#  '0x20aa72',
#  '0x22b676',
#  '0x1d30eb',
#  '0x1d615a',
#  '0x216e75',
#  '0x37dc8d',
#  '0x26228b',
#  '0x2fea59',
#  '0x33ad0c',
#  '0x2b556d',
#  '0x28aa4a',
#  '0x33d6ce',
#  '0x2368b3',
#  '0x318442',
#  '0x240e5f',
#  '0x209348',
#  '0x331db1',
#  '0x272cb4',
#  '0x2cac8c',
#  '0x2cb5e0',
#  '0x2b1063',
#  '0x2fcbb1',
#  '0x2bdd7f',
#  '0x26843f',
#  '0x2d075f',
#  '0x1e0814',
#  '0x233bae',
#  '0x2fc0bc',
#  '0x24489c',
#  '0x25668d',
#  '0x2d063d',
#  '0x295f41',
#  '0x286373',
#  '0x2cfc76',
#  '0x35680e',
#  '0x279f32',
#  '0x31005d',
#  '0x327110',
#  '0x23ae33',
#  '0x1e5033',
#  '0x2af4c2',
#  '0x32d7e3',
#  '0x29c272',
#  '0x2f4ef7',
#  '0x1f3968',
#  '0x1f5186',
#  '0x2a262f',
#  '0x218a97',
#  '0x258832',
#  '0x33c795',
#  '0x3369ec',
#  '0x2087ab',
#  '0x1e4fa1',
#  '0x264830',
#  '0x331e7d',
#  '0x27b5bc',
#  '0x2a15ae',
#  '0x27a24e',
#  '0x25689a',
#  '0x320824',
#  '0x1ee75e',
#  '0x299991',
#  '0x280fad',
#  '0x32a1d0',
#  '0x3812c5',
#  '0x30f9e1',
#  '0x23ed9f',
#  '0x33739d',
#  '0x280947',
#  '0x366201',
#  '0x314a5b',
#  '0x36e53f',
#  '0x1df2a9',
#  '0x2c526b',
#  '0x1d4ef5',
#  '0x2892a7',
#  '0x209f45',
#  '0x38970a',
#  '0x24a242',
#  '0x215026',
#  '0x2645b9',
#  '0x315be7',
#  '0x2114c1',
#  '0x33e1ad',
#  '0x2fa55e',
#  '0x21af66',
#  '0x378fc0',
#  '0x1c92d5',
#  '0x26da53',
#  '0x38ac67',
#  '0x2882c4',
#  '0x3845e1',
#  '0x31a096',
#  '0x353389',
#  '0x346d25',
#  '0x22a133',
#  '0x344d58',
#  '0x255dc6',
#  '0x246c85',
#  '0x2a91f8',
#  '0x26b626',
#  '0x25b73f',
#  '0x260202',
#  '0x214fab',
#  '0x20305a',
#  '0x21a93c',
#  '0x32be7a',
#  '0x38f9c4',
#  '0x1e7c1b',
#  '0x383c33',
#  '0x2bc2a7',
#  '0x1e7709',
#  '0x33823f',
#  '0x243c68',
#  '0x31b7d6',
#  '0x2493d5',
#  '0x376a66',
#  '0x340a23',
#  '0x1f6140',
#  '0x33b011',
#  '0x324a99',
#  '0x388752',
#  '0x32f901',
#  '0x232ecb',
#  '0x2db13a',
#  '0x1d0d01',
#  '0x1ccb9a',
#  '0x212926',
#  '0x208909',
#  '0x29bce7',
#  '0x2251a2',
#  '0x24d4cf',
#  '0x33c5c3',
#  '0x1f12ee',
#  '0x344df5',
#  '0x326a52',
#  '0x1f1049',
#  '0x2c4022',
#  '0x243015',
#  '0x2af049',
#  '0x251a89',
#  '0x216d1f',
#  '0x32eb01',
#  '0x229b1c',
#  '0x36d1c8',
#  '0x2d63c4',
#  '0x3544d5',
#  '0x252639',
#  '0x3514e4',
#  '0x289f70',
#  '0x1f20df',
#  '0x371955',
#  '0x28daff',
#  '0x1da9a8',
#  '0x2b52a4',
#  '0x303020',
#  '0x2cc068',
#  '0x2cf097',
#  '0x263f7a',
#  '0x2515f2',
#  '0x26edd7',
#  '0x1f3c89',
#  '0x35eaec',
#  '0x1ed5c0',
#  '0x1fa7d6',
#  '0x1e72c2',
#  '0x277598',
#  '0x2c9957',
#  '0x207bca',
#  '0x2acc08',
#  '0x34c917',
#  '0x2cd744',
#  '0x2683df',
#  '0x298f4c',
#  '0x3732bb',
#  '0x375660',
#  '0x2bfc81',
#  '0x2c2e86',
#  '0x30d62c',
#  '0x238a07',
#  '0x2b08c6',
#  '0x35bbca',
#  '0x2a0cf0',
#  '0x336d3f',
#  '0x31f25b',
#  '0x32e075',
#  '0x34986f',
#  '0x336e14',
#  '0x38b765',
#  '0x2305df',
#  '0x2b0893',
#  '0x3411a3',
#  '0x260221',
#  '0x1f27fb',
#  '0x34a5e6',
#  '0x2d912f',
#  '0x1f63d0',
#  '0x30b1da',
#  '0x1d23a2',
#  '0x1f9a1c',
#  '0x2b0964',
#  '0x2e2a4f',
#  '0x2a2e6a',
#  '0x245061',
#  '0x1d21ac',
#  '0x30006a',
#  '0x33c8fe',
#  '0x2b2a98',
#  '0x1f3954',
#  '0x2ada62',
#  '0x1f3caa',
#  '0x320331',
#  '0x240cb8',
#  '0x32ccc6',
#  '0x2a4d04',
#  '0x29cc7a',
#  '0x31a57b',
#  '0x333ba5',
#  '0x3589b4',
#  '0x32329b',
#  '0x30ea6c',
#  '0x270cb5',
#  '0x1ddc02',
#  '0x266a57',
#  '0x333633',
#  '0x24b3f9',
#  '0x37ebd5',
#  '0x269e3a',
#  '0x282df8',
#  '0x237d92',
#  '0x32fea9',
#  '0x36d369',
#  '0x38aa36',
#  '0x29914d',
#  '0x32ea1a',
#  '0x1cd511',
#  '0x30ff18',
#  '0x23d020',
#  '0x1f9d29',
#  '0x236017',
#  '0x2da6f3',
#  '0x2b5ee9',
#  '0x2ff62c',
#  '0x233f63',
#  '0x324551',
#  '0x2926a3',
#  '0x20bbda',
#  '0x1db6a2',
#  '0x1ee5f3',
#  '0x34a2e1',
#  '0x1e6635',
#  '0x32685c',
#  '0x2630f4',
#  '0x2ec329',
#  '0x2bf0db',
#  '0x1d0b56',
#  '0x32c0dd',
#  '0x233536',
#  '0x22eb0e',
#  '0x2019a3',
#  '0x2e2087',
#  '0x1d87d6',
#  '0x1e96ed',
#  '0x23a926',
#  '0x2b5fb4',
#  '0x365ab8',
#  '0x21947b',
#  '0x297f8c',
#  '0x25ce61',
#  '0x2ac089',
#  '0x27342f',
#  '0x2d4b05',
#  '0x20cfb4',
#  '0x307d07',
#  '0x29ee79',
#  '0x2389e1',
#  '0x2bcf89',
#  ...]

# %%
# Write the predictions into the csv file first
csv_file_name = 'output.csv'

with open(csv_file_name, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    
    for row in actual_pred:
        if not isinstance(row, list):
            row = [row]  # Convert a single value into a list so that the spliting up of words do not occur
        csvwriter.writerow(row)

# %%
# Set headers
new_column_data = list(test_id)
new_column_header = 'id'
existing_column_header = 'emotion'

# Read the existing data from the above CSV file
existing_data = []
with open('output.csv', 'r', newline='') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        existing_data.append(row)

# Combine the new column data with the existing data
combined_data = [[new_column_header, existing_column_header]]
for i, row in enumerate(existing_data):
    combined_data.append([new_column_data[i], row[0]])

# Write the combined data to a new CSV file
with open('updated_emotions.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(combined_data)
